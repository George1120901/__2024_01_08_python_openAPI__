# %% [markdown]
# ### **<參考來源>**

# %%
# 2024.07.11  V0.96 --> OK (v0.9 final) 
# V0.96 --> copy of V0.95_2
# convert_mp4_to_mp3(input_file, output_file) : '-q:a', '2',   -->預設
# convert_mp4_to_mp3重複(同檔名.mp3)對應 -3 --> open 後,close
# file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序

from pytube import YouTube
import re
import subprocess
import os

def streams_analysis(url):
    yt = YouTube(url) 
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))
    for st in yt.streams:
        print(st)
    print('media格式分析完成')

def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 

def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*'] # window檔案格式排除符號
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱(檔名) : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path=output_path,filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    

    try:
        f = open(f'{output_path}/yt_audio_{yt_title}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/yt_audio_{yt_title}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

# url = 'https://www.youtube.com/watch?v=sWdGVa4vz5E'  # 曲目:蔡琴,Tsai Chin,情人的眼泪,明日之歌,飘零的落花,月光小夜曲,70后80后90后最喜欢的华语金曲,Appreciation of Chinese songs

work_item = int(input('輸入 ( 1 :分析   2:下載   其他:跳出執行 )'))
if work_item == 1:
   url = str(input("輸入影音網址 (Enter the url of media) : ")) 
   streams_analysis(url) 
elif work_item == 2:
    url = str(input("輸入影音網址(Enter the url of media) : "))  
    dir_name = 'youtube'  # 設定工作/儲存檔案之資料夾
    file_path = f'c:/{dir_name}/filename.ext'
    output_path = os.path.dirname(file_path)
    print(f'out_path >>> {output_path}') 
    dir_path(output_path)
    yt_title = get_audio_only(url)  # 返回結果方式
    convert_mp4_to_mp3(f'{output_path}/yt_audio_{yt_title}.mp4', f'{output_path}/yt_audio_{yt_title}.mp3')
else:
     print('輸入 ( 1 :分析   2:下載   其他:跳出執行 )')


# media 長度 01:06:05 mp4容量大小62,678KB mp3容量大小88,762KB 處理耗時1m 45.2s

# %% [markdown]
# ### **<convert_mp4_to_mp3 only>**

# %%
# v0.1.0
# base 2024.07.11  V0.96 --> OK (v0.9 final) from "ytGetAudioOnly_0.46.ipynb" V0.96


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '1',
        output_file
    ]
    
    try:
        f = open(f'{output_path}/yt_audio_{yt_title}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/yt_audio_{yt_title}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'yt_audio_The Best Nocturnes by Chopin .mp4'
file_path = f'c:/{dir_name}/{file_name}'

basename = os.path.basename(file_path)
print(basename)

basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
print(basename_without_ext)

output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 

dir_path(output_path)
# yt_title = get_audio_only(url)  # 返回結果方式
# convert_mp4_to_mp3(f'{output_path}/yt_audio_{yt_title}.mp4', f'{output_path}/yt_audio_{yt_title}.mp3')

convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')


# media 長度 01:53:55 mp4容量大小108,035KB mp3容量大小70,408KB 處理耗時1m 13.7s ('-q:a', '2',)
# media 長度 01:53:55 mp4容量大小108,035KB mp3容量大小83,114KB 處理耗時1m 13.7s ('-q:a', '1',)
# Out:
# yt_audio_The Best Nocturnes by Chopin .mp4
# yt_audio_The Best Nocturnes by Chopin
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# 轉換成功！輸出文件位於: yt_audio_The Best Nocturnes by Chopin .mp3

# %%
# v0.1.1
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
## convert_mp4_to_mp3重複(同檔名.mp3)對應修訂


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '1',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'yt_audio_The Best Nocturnes by Chopin .mp4'
file_path = f'c:/{dir_name}/{file_name}'

basename = os.path.basename(file_path)
print(f'轉換檔案 : {basename}')

basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
print(f'檔案名 : {basename_without_ext}')

output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 

dir_path(output_path)

convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')


# media 長度 01:53:55 mp4容量大小108,035KB mp3容量大小70,408KB 處理耗時1m 13.7s ('-q:a', '2',)
# media 長度 01:53:55 mp4容量大小108,035KB mp3容量大小83,114KB 處理耗時1m 15.xs ('-q:a', '1',)
# Out:
# 轉換檔案 : yt_audio_The Best Nocturnes by Chopin .mp4
# 檔案名 : yt_audio_The Best Nocturnes by Chopin
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# yt_audio_The Best Nocturnes by Chopin .mp4
# c:/Users/Lu/Documents/youtube/yt_audio_The Best Nocturnes by Chopin .mp3 已存在

# %% [markdown]
# ~ 單一檔案轉換
# ---
# ---
# 複數檔案轉換 ~

# %%
# v0.1.2.0
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
## f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '1',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
# file_name = 'yt_audio_The Best Nocturnes by Chopin .mp4'
file_name = ''
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    file_path = f'c:/{dir_name}/{file_name}'
    
    
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')



# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小55,090KB 處理耗時xm xx.xs ('-q:a', '1',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_The Best _Chopin_ Classical Piano Music.mp4']
# 轉換檔案 : yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 檔案名 : yt_audio_The Best _Chopin_ Classical Piano Music
# c:/Users/Lu/Documents/youtube/yt_audio_The Best _Chopin_ Classical Piano Music.mp3 已存在

# %%
# v0.1.2.1
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
## f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
# file_name = 'yt_audio_The Best Nocturnes by Chopin .mp4'
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    #file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    print(file_name)
    
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')


# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小55,090KB 處理耗時xm xx.xs ('-q:a', '1',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_The Best _Chopin_ Classical Piano Music.mp4']
# c:/Users/Lu/Documents/youtube/test.txt
# yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 轉換檔案 : test.txt
# 檔案名 : test
# ffmpeg轉換過程中發生錯誤: Command '['ffmpeg', '-i', 'test.txt', '-vn', '-acodec', 'libmp3lame', '-q:a', '2', 'test.mp3']' returned non-zero exit status 4294967294.
# ffmpeg命令輸出: ffmpeg version 7.0.1-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [in#0 @ 000001b54b867600] Error opening input: No such file or directory
# Error opening input file test.txt.
# Error opening input files: No such file or directory

# %%
# v0.1.2.2
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
## f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
# file_name = 'yt_audio_The Best Nocturnes by Chopin .mp4'
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    file_path = f'c:/{dir_name}/{file_name}'
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')


# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_The Best _Chopin_ Classical Piano Music.mp4']
# 轉換檔案 : yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 檔案名 : yt_audio_The Best _Chopin_ Classical Piano Music
# 轉換成功！輸出文件位於: yt_audio_The Best _Chopin_ Classical Piano Music.mp3

# %%
# v0.1.2.3
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
## f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')


# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4\n', 'yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4\n', 'yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4']
# c:/Users/Lu/Documents/youtube/yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
#
# 轉換檔案 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
#
# 檔案名 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven
# ffmpeg轉換過程中發生錯誤: Command '['ffmpeg', '-i', 'yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4\n', '-vn', '-acodec', 'libmp3lame', '-q:a', '2', 'yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp3']' returned non-zero exit status 4294967274.
# ffmpeg命令輸出: ffmpeg version 7.0.1-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [in#0 @ 00000159a72a1000] Error opening input: Invalid argument
# Error opening input file yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
# .
# Error opening input files: Invalid argument
#
# c:/Users/Lu/Documents/youtube/yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
#
# 轉換檔案 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
#
# 檔案名 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner)
# ffmpeg轉換過程中發生錯誤: Command '['ffmpeg', '-i', 'yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4\n', '-vn', '-acodec', 'libmp3lame', '-q:a', '2', 'yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp3']' returned non-zero exit status 4294967274.
# ffmpeg命令輸出: ffmpeg version 7.0.1-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [in#0 @ 00000223de791000] Error opening input: Invalid argument
# Error opening input file yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# .
# Error opening input files: Invalid argument
#
# c:/Users/Lu/Documents/youtube/yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
# 轉換檔案 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
# 檔案名 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven
# 轉換成功！輸出文件位於: yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp3

# %%
# v0.1.2.4
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
## f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫
## convert_lists.txt 有多個檔名
## def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{basename}' --> NG
## def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{file_path}' --> NG

#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    print(input_file)
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    #convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')

    convert_mp4_to_mp3(f'{file_path}', f'{basename_without_ext}.mp3')



# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4\n']
# c:/Users/Lu/Documents/youtube/yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
#
# 轉換檔案 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
#
# 檔案名 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven
# c:/Users/Lu/Documents/youtube/yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
#
# ffmpeg轉換過程中發生錯誤: Command '['ffmpeg', '-i', 'c:/Users/Lu/Documents/youtube/yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4\n', '-vn', '-acodec', 'libmp3lame', '-q:a', '2', 'yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp3']' returned non-zero exit status 4294967274.
# ffmpeg命令輸出: ffmpeg version 7.0.1-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [in#0 @ 000002bfd8430f80] Error opening input: Invalid argument
# Error opening input file c:/Users/Lu/Documents/youtube/yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
# .
# Error opening input files: Invalid argument

# %%
# v0.1.2.0 for reckeck
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
## f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫
## convert_lists.txt 僅有單一檔名


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
# file_name = 'yt_audio_The Best Nocturnes by Chopin .mp4'
file_name = ''
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    file_path = f'c:/{dir_name}/{file_name}'
    
    
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')



# media 長度 03:00:00 mp4容量大小170,695KB mp3容量大小206,432KB 處理耗時2m 43.5s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4']
# 轉換檔案 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
# 檔案名 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven
# 轉換成功！輸出文件位於: yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp3

# %%
# v0.1.1 for recheck
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
## convert_mp4_to_mp3重複(同檔名.mp3)對應修訂


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '1',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                    print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4'
file_path = f'c:/{dir_name}/{file_name}'

basename = os.path.basename(file_path)
print(f'轉換檔案 : {basename}')

basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
print(f'檔案名 : {basename_without_ext}')

output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 

dir_path(output_path)

convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')


# media 長度 03:00:00 mp4容量大小170,695KB mp3容量大小237,512KB 處理耗時2m 47.2s ('-q:a', '1',)
# Out:
# 轉換檔案 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp4
# 檔案名 : yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# 轉換成功！輸出文件位於: yt_audio_Classical_Music_for_Studying_Working_Relaxing-Mozart_Beethoven.mp3

# %%
# v0.1.2.5
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
# f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫
## convert_lists.txt 有多個檔名
## def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{basename_without_ext}.mp4' --> ok ???


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    print(input_file)
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '4',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    #convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')  # input_file =  f'{basename}' --> NG

    convert_mp4_to_mp3(f'{basename_without_ext}.mp4', f'{basename_without_ext}.mp3')  # input_file =  f'{basename_without_ext}.mp4' --> ok ???



# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_The Best _Chopin_ Classical Piano Music.mp4\n', 'yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4']
# c:/Users/Lu/Documents/youtube/yt_audio_The Best _Chopin_ Classical Piano Music.mp4
#
# 轉換檔案 : yt_audio_The Best _Chopin_ Classical Piano Music.mp4
#
# 檔案名 : yt_audio_The Best _Chopin_ Classical Piano Music
# yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 轉換成功！輸出文件位於: yt_audio_The Best _Chopin_ Classical Piano Music.mp3
# c:/Users/Lu/Documents/youtube/yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 轉換檔案 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 檔案名 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner)
# yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 轉換成功！輸出文件位於: yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp3

# %%
# v0.1.2.5
# base 2024.07.11  V0.96 --> OK (v0.9 final) 
# from "ytGetAudioOnly_0.46.ipynb" V0.96
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
# f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫
## convert_lists.txt 有多個檔名
## def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{basename_without_ext}.mp4' --> ok ???
## def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{output_path}/{basename}' --> NG


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    print(input_file)
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '4',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for file_name in convert_list:
    file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    # convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')  # input_file =  f'{basename}' --> NG

    convert_mp4_to_mp3(f'{basename_without_ext}.mp4', f'{basename_without_ext}.mp3')  # input_file =  f'{basename_without_ext}.mp4' --> ok ???

    # convert_mp4_to_mp3(f'{output_path}/{basename}', f'{basename_without_ext}.mp3') #--> NG

# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_The Best _Chopin_ Classical Piano Music.mp4\n', 'yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4']
# c:/Users/Lu/Documents/youtube/yt_audio_The Best _Chopin_ Classical Piano Music.mp4
#
# 轉換檔案 : yt_audio_The Best _Chopin_ Classical Piano Music.mp4
#
# 檔案名 : yt_audio_The Best _Chopin_ Classical Piano Music
# yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 轉換成功！輸出文件位於: yt_audio_The Best _Chopin_ Classical Piano Music.mp3
# c:/Users/Lu/Documents/youtube/yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 轉換檔案 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 檔案名 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner)
# yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# c:/Users/Lu/Documents/youtube/yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp3 已存在

# %% [markdown]
# ### **Python: Read Text File into List**
#
# https://careerkarma.com/blog/python-read-text-file-into-list/
#
# Question:convert "lists.txt' to list of python
#
# Note:
# Every ingredient ends in the “\n” character. This character denotes a new line. We can remove this character by using the replace() method:
# 每個成分都以“\n”字元結尾。該字元表示換行。我們可以使用replace()方法刪除這個字元：
# **.replace("\n", "")**

# %%
# v0.1.2.6  -->2024.07.17 ok ---> v1.2 final
# base 2024.07.11  V0.96 (ytGetAudioOnly_0.4.6.ipynb)--> OK (v0.9 final) 
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
# f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫
# convert_lists.txt 有多個檔名
# def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{basename_without_ext}.mp4' --> ok ???
# def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{output_path}/{basename}' --> NG
## remove "\n" by using the replace() method in list when reads each line of text from our text file

#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    print(input_file)
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for i in convert_list:
    file_name = i.replace("\n", "") # input_file =  f'{basename}' --> OK
    file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')
    
    # convert_mp4_to_mp3(f'{basename_without_ext}.mp4', f'{basename_without_ext}.mp3')  # input_file =  f'{basename_without_ext}.mp4' --> ok ???

    # convert_mp4_to_mp3(f'{output_path}/{basename}', f'{basename_without_ext}.mp3') #--> NG

# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_The Best _Chopin_ Classical Piano Music.mp4\n', 'yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4']
# c:/Users/Lu/Documents/youtube/yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 轉換檔案 : yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 檔案名 : yt_audio_The Best _Chopin_ Classical Piano Music
# yt_audio_The Best _Chopin_ Classical Piano Music.mp4
# 轉換成功！輸出文件位於: yt_audio_The Best _Chopin_ Classical Piano Music.mp3
# c:/Users/Lu/Documents/youtube/yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 轉換檔案 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 檔案名 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner)
# yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 轉換成功！輸出文件位於: yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp3

# %%
# v0.1.2.7pass  --> from v0.1.2.6
# base 2024.07.11  V0.96 (ytGetAudioOnly_0.4.6.ipynb)--> OK (v0.9 final) 
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
# f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫
# convert_lists.txt 有多個檔名
# def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{basename_without_ext}.mp4' --> ok ???
# def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{output_path}/{basename}' --> NG
# remove "\n" by using the replace() method in list when reads each line of text from our text file
## 副檔名 :basename_extension = os.path.splitext(os.path.basename(file_path))[1] --> pass

#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    print(input_file)
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                print("無法獲取 ffmpeg 錯誤輸出。")
   

dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r')
convert_list = f.readlines()
print(convert_list)
f.close()

for i in convert_list:
    file_name = i.replace("\n", "") # input_file =  f'{basename}' --> OK
    file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')
    
    # convert_mp4_to_mp3(f'{basename_without_ext}.mp4', f'{basename_without_ext}.mp3')  # input_file =  f'{basename_without_ext}.mp4' --> ok ???

    # convert_mp4_to_mp3(f'{output_path}/{basename}', f'{basename_without_ext}.mp3') #--> NG

# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube
# 資料夾 c:/Users/Lu/Documents/youtube existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube
# 目前資料夾c:\Users\Lu\Documents\youtube
# ['yt_audio_The Best _Chopin_ Classical Piano Music.mp4\n', 'yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4']
# yt_audio_The Best _Chopin_ Classical Piano Music.mp4
#
# c:/Users/Lu/Documents/youtube/yt_audio_The Best _Chopin_ Classical Piano Music.mp4
#
# 轉換檔案 : yt_audio_The Best _Chopin_ Classical Piano Music.mp4
#
# 檔案名 : yt_audio_The Best _Chopin_ Classical Piano Music
# yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# c:/Users/Lu/Documents/youtube/yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 轉換檔案 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner).mp4
# 檔案名 : yt_audio_Soft Classical Piano - Relaxing Piano Pieces (Luke Faulkner)

# %%
# v0.1.2.8  --> from v0.1.2.6
# base 2024.07.11  V0.96 (ytGetAudioOnly_0.4.6.ipynb)--> OK (v0.9 final) 
# convert_mp4_to_mp3重複(同檔名.mp3)對應修訂
# f = open('convert_lists.txt','r') 以'convert_lists.txt'作重覆執行多檔案下載合併程序之資料庫
# convert_lists.txt 有多個檔名
# def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{basename_without_ext}.mp4' --> ok ???
# def convert_mp4_to_mp3(input_file, output_file):之input_file =  f'{output_path}/{basename}' --> NG
# remove "\n" by using the replace() method in list when reads each line of text from our text file
# 副檔名 :basename_extension = os.path.splitext(os.path.basename(file_path))[1] --> pass
## f = open('convert_lists.txt','r',encoding='utf-8')追加encoding='utf-8'


#import re
import subprocess
import os


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def convert_mp4_to_mp3(input_file, output_file):
    print(input_file)
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        f = open(f'{basename_without_ext}.mp3','r',encoding= 'utf-8')  # convert_mp4_to_mp3重複(同檔名.mp3)對應 -3
        print(f'{output_path}/{basename_without_ext}.mp3 已存在')
        f.close()
    except:    
        try:
            result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
            print("轉換成功！輸出文件位於:", output_file)
        except subprocess.CalledProcessError as e:
            print("ffmpeg轉換過程中發生錯誤:", e)
            if e.stderr:
                print("ffmpeg命令輸出:", e.stderr)
            else:
                print("無法獲取 ffmpeg 錯誤輸出。")
   

# dir_name = 'Users/Lu/Documents/youtube'  # 設定工作/儲存檔案之資料夾
dir_name = 'youtube'
file_name = 'filename.ext'
file_path = f'c:/{dir_name}/{file_name}'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}') 
dir_path(output_path)

f = open('convert_lists.txt','r',encoding='utf-8')
convert_list = f.readlines()
print(convert_list)
f.close()

for i in convert_list:
    file_name = i.replace("\n", "") # input_file =  f'{basename}' --> OK
    file_path = f'c:/{dir_name}/{file_name}'
    print(file_path)
    basename = os.path.basename(file_path)
    print(f'轉換檔案 : {basename}')
    basename_without_ext = os.path.splitext(os.path.basename(file_path))[0]
    print(f'檔案名 : {basename_without_ext}')
    convert_mp4_to_mp3(f'{basename}', f'{basename_without_ext}.mp3')
    
    # convert_mp4_to_mp3(f'{basename_without_ext}.mp4', f'{basename_without_ext}.mp3')  # input_file =  f'{basename_without_ext}.mp4' --> ok ???

    # convert_mp4_to_mp3(f'{output_path}/{basename}', f'{basename_without_ext}.mp3') #--> NG

# media 長度 01:20:21 mp4容量大小76,210KB mp3容量大小47,587KB 處理耗時0m 46.2s ('-q:a', '2',)
# Out:
# out_path >>> c:/youtube
# 資料夾 c:/youtube existed
# 預設檔案位置 c:/youtube
# 目前資料夾c:\youtube
# ['yt_audio_那些年一起唱過的經典(1).mp4\n', 'yt_audio_那些年一起唱過的經典(5).mp4\n', 'yt_audio_民歌精選.mp4']
# c:/youtube/yt_audio_那些年一起唱過的經典(1).mp4
# 轉換檔案 : yt_audio_那些年一起唱過的經典(1).mp4
# 檔案名 : yt_audio_那些年一起唱過的經典(1)
# yt_audio_那些年一起唱過的經典(1).mp4
# 轉換成功！輸出文件位於: yt_audio_那些年一起唱過的經典(1).mp3
# c:/youtube/yt_audio_那些年一起唱過的經典(5).mp4
# 轉換檔案 : yt_audio_那些年一起唱過的經典(5).mp4
# 檔案名 : yt_audio_那些年一起唱過的經典(5)
# yt_audio_那些年一起唱過的經典(5).mp4
# 轉換成功！輸出文件位於: yt_audio_那些年一起唱過的經典(5).mp3
# c:/youtube/yt_audio_民歌精選.mp4
# 轉換檔案 : yt_audio_民歌精選.mp4
# 檔案名 : yt_audio_民歌精選
# yt_audio_民歌精選.mp4
# 轉換成功！輸出文件位於: yt_audio_民歌精選.mp3
