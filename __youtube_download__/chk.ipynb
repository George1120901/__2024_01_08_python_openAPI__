# %%
# 使用模組
from pytube import YouTube

url='https://youtube.com/live/o6HQepxxDlo'   # 2023_11_10_下午
yt = YouTube(url)

# 影片格式分析
print(f'標題: {yt.title}')              # 影片標題
print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
print(f'作者: {yt.author}')             # 影片作者
print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
print(f'觀看數: {yt.views}')            # 影片觀看數

# 分析
print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
# print(yt.streams.all())  # all()-->useless
print('影片支援畫質數: ',len(yt.streams))

for st in yt.streams:
  print(st)
# Out:
# 標題: 2023_11_10_下午
# 長度(s): 10055
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/o6HQepxxDlo/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDfukQ0xJCh4CLKvLbNK4aegmeIQg
# 觀看數: 30
# ---------------------------------------------------------------------------
# RegexMatchError                           Traceback (most recent call last)
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:181, in YouTube.fmt_streams(self)
#     180 try:
# --> 181     extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     182 except exceptions.ExtractError:
#     183     # To force an update to the js file, we clear the cache and retry
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\extract.py:409, in apply_signature(stream_manifest, vid_info, js)
#     401 """Apply the decrypted signature to the stream manifest.
#     402
#     403 :param dict stream_manifest:
#    (...)
#     407
#     408 """
# --> 409 cipher = Cipher(js=js)
#     411 for i, stream in enumerate(stream_manifest):
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:43, in Cipher.__init__(self, js)
#      38 self.js_func_patterns = [
#      39     r"\w+\.(\w+)\(\w,(\d+)\)",
#      40     r"\w+\[(\"\w+\")\]\(\w,(\d+)\)"
#      41 ]
# ---> 43 self.throttling_plan = get_throttling_plan(js)
#      44 self.throttling_array = get_throttling_function_array(js)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:405, in get_throttling_plan(js)
#     393 """Extract the "throttling plan".
#     394
#     395 The "throttling plan" is a list of tuples used for calling functions
#    (...)
#     403     The full function code for computing the throttlign parameter.
#     404 """
# --> 405 raw_code = get_throttling_function_code(js)
#     407 transform_start = r"try{"
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:311, in get_throttling_function_code(js)
#     310 # Begin by extracting the correct function name
# --> 311 name = re.escape(get_throttling_function_name(js))
#     313 # Identify where the function is defined
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:296, in get_throttling_function_name(js)
#     294                 return array[int(idx)]
# --> 296 raise RegexMatchError(
#     297     caller="get_throttling_function_name", pattern="multiple"
#     298 )
#
# RegexMatchError: get_throttling_function_name: could not find match for multiple
#
# During handling of the above exception, another exception occurred:
#
# RegexMatchError                           Traceback (most recent call last)
# Cell In[1], line 16
#      13 print(f'觀看數: {yt.views}')            # 影片觀看數
#      15 # 分析
# ---> 16 print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
#      17 # print(yt.streams.all())  # all()-->useless
#      18 print('影片支援畫質數: ',len(yt.streams))
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:188, in YouTube.fmt_streams(self)
#     186     pytube.__js__ = None
#     187     pytube.__js_url__ = None
# --> 188     extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     190 # build instances of :class:`Stream <Stream>`
#     191 # Initialize stream objects
#     192 for stream in stream_manifest:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\extract.py:409, in apply_signature(stream_manifest, vid_info, js)
#     400 def apply_signature(stream_manifest: Dict, vid_info: Dict, js: str) -> None:
#     401     """Apply the decrypted signature to the stream manifest.
#     402
#     403     :param dict stream_manifest:
#    (...)
#     407
#     408     """
# --> 409     cipher = Cipher(js=js)
#     411     for i, stream in enumerate(stream_manifest):
#     412         try:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:43, in Cipher.__init__(self, js)
#      37 self.transform_map = get_transform_map(js, var)
#      38 self.js_func_patterns = [
#      39     r"\w+\.(\w+)\(\w,(\d+)\)",
#      40     r"\w+\[(\"\w+\")\]\(\w,(\d+)\)"
#      41 ]
# ---> 43 self.throttling_plan = get_throttling_plan(js)
#      44 self.throttling_array = get_throttling_function_array(js)
#      46 self.calculated_n = None
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:405, in get_throttling_plan(js)
#     392 def get_throttling_plan(js: str):
#     393     """Extract the "throttling plan".
#     394
#     395     The "throttling plan" is a list of tuples used for calling functions
#    (...)
#     403         The full function code for computing the throttlign parameter.
#     404     """
# --> 405     raw_code = get_throttling_function_code(js)
#     407     transform_start = r"try{"
#     408     plan_regex = re.compile(transform_start)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:311, in get_throttling_function_code(js)
#     302 """Extract the raw code for the throttling function.
#     303
#     304 :param str js:
#    (...)
#     308     The name of the function used to compute the throttling parameter.
#     309 """
#     310 # Begin by extracting the correct function name
# --> 311 name = re.escape(get_throttling_function_name(js))
#     313 # Identify where the function is defined
#     314 pattern_start = r"%s=function\(\w\)" % name
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\cipher.py:296, in get_throttling_function_name(js)
#     293                 array = [x.strip() for x in array]
#     294                 return array[int(idx)]
# --> 296 raise RegexMatchError(
#     297     caller="get_throttling_function_name", pattern="multiple"
#     298 )
#
# RegexMatchError: get_throttling_function_name: could not find match for multiple
