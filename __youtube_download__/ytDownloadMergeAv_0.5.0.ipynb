# %% [markdown]
# ### **HTTP Error 400: Bad Request #1973**
# https://github.com/pytube/pytube/issues/1973
# issue date:2024.07.17
#
# **>working issue-1**
# from:KhurramRana commented 2 days ago
# Place these lines of code at the top of your codebase and the issue will be fixed.
#
#         from pytube. innertube import _default_clients
#
#         _default_clients[ "ANDROID"][ "context"]["client"]["clientVersion"] = "19.08.35"
#         _default_clients["IOS"]["context"]["client"]["clientVersion"] = "19.08.35"
#         _default_clients[ "ANDROID_EMBED"][ "context"][ "client"]["clientVersion"] = "19.08.35"
#         _default_clients[ "IOS_EMBED"][ "context"]["client"]["clientVersion"] = "19.08.35"
#         _default_clients["IOS_MUSIC"][ "context"]["client"]["clientVersion"] = "6.41"
#         _default_clients[ "ANDROID_MUSIC"] = _default_clients[ "ANDROID_CREATOR" ]

# %%
# issue for HTTP Error 400_Bad Request of pytube
# https://github.com/pytube/pytube/issues/1973  
# issue date:2024.07.17 

# 使用模組
from pytube import YouTube
from pytube. innertube import _default_clients

_default_clients[ "ANDROID"][ "context"]["client"]["clientVersion"] = "19.08.35"
_default_clients["IOS"]["context"]["client"]["clientVersion"] = "19.08.35"
_default_clients[ "ANDROID_EMBED"][ "context"][ "client"]["clientVersion"] = "19.08.35"
_default_clients[ "IOS_EMBED"][ "context"]["client"]["clientVersion"] = "19.08.35"
_default_clients["IOS_MUSIC"][ "context"]["client"]["clientVersion"] = "6.41"
_default_clients[ "ANDROID_MUSIC"] = _default_clients[ "ANDROID_CREATOR" ]



yt = YouTube('https://youtube.com/live/4J4UWmFHp1s')

# 影片格式分析
print(yt.title)           # 影片標題
print(yt.length)          # 影片長度 ( 秒 )
print(yt.author)          # 影片作者
print(yt.channel_url)     # 影片作者頻道網址
print(yt.thumbnail_url)   # 影片縮圖網址
print(yt.views)           # 影片觀看數
# 分析
# print(yt.streams)
print(len(yt.streams))
for st in yt.streams:
  print(st)

# %% [markdown]
# ### 下載Youtube影片
# ytDloadMergeV0.3.ipynb --> ~2024.06.20止
# ytDloadMergeV0.4.ipynb -->  2024.06.20~ 起
# Pytube：Youtube影片下載

# %%
# 使用模組
from pytube import YouTube

url='https://youtube.com/live/o6HQepxxDlo'   # 2023_11_10_下午
yt = YouTube(url)

# 影片格式分析
print(f'標題: {yt.title}')              # 影片標題
print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
print(f'作者: {yt.author}')             # 影片作者
print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
print(f'觀看數: {yt.views}')            # 影片觀看數

# 分析
print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
# print(yt.streams.all())  # all()-->useless
print('影片支援畫質數: ',len(yt.streams))

for st in yt.streams:
  print(st)
# Out:
# 標題: 2023_11_10_下午
# 長度(s): 10055
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/o6HQepxxDlo/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDfukQ0xJCh4CLKvLbNK4aegmeIQg
# 觀看數: 30
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
# 用itag分別下載聲音&影像  _ ok
## audio(itag=140) 音訊取樣率44KHz
## vedio(itag=137) 為1080p
## 使用 yt.title 為檔名
from pytube import YouTube

url='https://youtube.com/live/o6HQepxxDlo'   # 2023_11_10_下午
yt = YouTube(url) 

yt_title=yt.title
itag_Audio = 140
itag_Vedio = 137
itag_List = [itag_Audio,itag_Vedio]
for i in itag_List:
    stream = yt.streams.get_by_itag(i)
    stream.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'python_{yt_title}_itag({i}).mp4', skip_existing=True, max_retries=0)
    print(f'python_{yt_title}_itag({i})完成')
print('downdload完成')
# Out:
# python_2023_11_20_下午_itag(140)完成
# python_2023_11_20_下午_itag(137)完成
# downdload完成

# %%
#  可成功完成 vedio+audio 之 merage((基本式樣)+(ubprocess.TimeoutExpired檢查)+(增加執行內容信息))
## 採用案 -- ok
import subprocess

def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行命令:", ' '.join(command))  # 增加執行內容信息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=60)
        # 增加timeout=60之subprocess.TimeoutExpired檢查
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)

merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag(merge).mp4')
# Out:
# 執行命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag(merge).mp4

# %%
import os

os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4')
os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4')
print('影像&音訊檔案刪除成功,合併完成！')
# Out:
# 影像&音訊檔案刪除成功,合併完成！

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ###  可成功完成 vedio+audio 之 merage
# ##### ((基本式樣)+(ubprocess.TimeoutExpired檢查)+(增加執行內容信息))
# ##### + 如果嘗試用 UTF-8 解碼失敗，使用 CP950 解碼
#
# #### 備用案 -- ok

# %%
# 可成功完成 vedio+audio 之 merage
# (基本式樣V0.1)+(ubprocess.TimeoutExpired檢查)+(增加執行內容訊息)+(UTF-8解碼失敗，使用CP950解碼)

import subprocess

def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)

merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag-5.mp4')
# Out:
# 執行命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag-5.mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_11_20_下午_itag-5.mp4

# %% [markdown]
# ++++++++++++++++++++++++++++++++++++++++++++++
# ### **整合**
# * V0.3.2 -->V0.4.0完成 (2024.06.15止-->final)
# *  ~v0.4.0 為單一下載點 for normal downloading

# %%
# V0.3.1
from pytube import YouTube
import subprocess
import os

def media_contents(url):
    #yt = YouTube(url)  # ex.2023_11_16_上午

    # 影片格式分析
    print(yt.title)           # 影片標題
    print(yt.length)          # 影片長度 ( 秒 )
    print(yt.author)          # 影片作者
    print(yt.channel_url)     # 影片作者頻道網址
    print(yt.thumbnail_url)   # 影片縮圖網址
    print(yt.views)           # 影片觀看數

    # 分析
    print(yt.streams)  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print(len(yt.streams))

    for st in yt.streams:
        print(st)

    print('media格式分析完成')



def download_video_and_audio(url):
    # yt = YouTube(url) 
    yt_title = yt.title
    itag_Audio = 140
    itag_Vedio = 137
    itag_List = [itag_Audio,itag_Vedio]
    for i in itag_List:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'python_{yt_title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt_title}_itag({i})完成')
    print('downdload完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)

 
#url = input("Enter the url of media : ")   
url='https://youtube.com/live/Mg3WFru-AXY'  # 2023_11_20_下午
yt = YouTube(url)  
media_contents(url)
download_video_and_audio(url)
merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag-5.mp4')

#os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4')
#os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4')
#print('影像&音訊檔案刪除成功,合併完成！')
# Out:
# 2023_11_16_早上
# 12535
# 徐國堂
# https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# https://i.ytimg.com/vi/Mg3WFru-AXY/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDeQlK0A-2EkqfEgCecGHk3L4u1_A
# 20
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 9
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# python_2023_11_16_早上_itag(140)完成
# python_2023_11_16_早上_itag(137)完成
# downdload完成
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 76
#      74 media_contents(url)
#      75 download_video_and_audio(url)
# ---> 76 merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag-5.mp4')
#      78 #os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4')
#      79 #os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4')
#      80 #print('影像&音訊檔案刪除成功,合併完成！')
#
# NameError: name 'yt_title' is not defined

# %%
# 確認 v0.3.1 (NameError: name 'yt_title' is not defined)-->直接使用yt.title
import subprocess

def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)

 
#url = input("Enter the url of media : ")   
url='https://youtube.com/live/Mg3WFru-AXY'  # 2023_11_20_下午
yt = YouTube(url)  
# media_contents(url)
# download_video_and_audio(url)
itag_Audio = 140
itag_Vedio = 137
merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag-5.mp4')
# Out:
# 執行命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_11_16_早上_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_11_16_早上_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_11_16_早上_itag-5.mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_11_16_早上_itag-5.mp4

# %%
# V0.3.2  --> ok
from pytube import YouTube
import subprocess
import os

def media_contents(url):
    #yt = YouTube(url)  # ex.2023_11_16_下午

    # 影片格式分析
    print(yt.title)           # 影片標題
    print(yt.length)          # 影片長度 ( 秒 )
    print(yt.author)          # 影片作者
    print(yt.channel_url)     # 影片作者頻道網址
    print(yt.thumbnail_url)   # 影片縮圖網址
    print(yt.views)           # 影片觀看數

    # 分析
    print(yt.streams)  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print(len(yt.streams))

    for st in yt.streams:
        print(st)

    print('media格式分析完成')



def download_video_and_audio(url,itag_Vedio,itag_Audio):
    # yt = YouTube(url) 
    # yt_title = yt.title
    # itag_Audio = 140
    # itag_Vedio = 137
    print('downdloading of video & audio .....')
    # itag_List = [itag_Audio,itag_Vedio]
    itag_List = [itag_Vedio,itag_Audio]
    for i in itag_List:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('downdload完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)

 
#url = input("Enter the url of media : ")   
url='https://youtube.com/live/Qxg3vr2BBpU'  # 2023_11_16_下午
yt = YouTube(url) 
itag_Audio = 140
itag_Vedio = 137 
media_contents(url)
download_video_and_audio(url,itag_Vedio,itag_Audio)
merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag(merge).mp4')
#<2023_11_16_下午> media 長度 02:04:20 容量大小508,810KB 處理耗時4m 10.5s

#os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Vedio}).mp4')
#os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt_title}_itag({itag_Audio}).mp4')
#print('影像&音訊檔案刪除成功,合併完成！')
# Out:
# 2023_11_16_下午
# 7460
# 徐國堂
# https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# https://i.ytimg.com/vi/Qxg3vr2BBpU/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLBn_4b-SDU7p-OXvl6mdefjByOfLA
# 19
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 9
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_11_16_下午_itag(137)完成
# python_2023_11_16_下午_itag(140)完成
# downdload完成
# 執行命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_11_16_下午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_11_16_下午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_11_16_下午_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_11_16_下午_itag(merge).mp4

# %%
# V0.4.0 -->完成 (2024.06.15止-->final)
# V0.4.0 -->base V0.3.2
# ~v0.4.0 為單一下載點 for normal downloading
from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print('標題: ',yt.title)                 # 影片標題
    print('長度 ( 秒 ): ',yt.length)         # 影片長度 ( 秒 )
    print('作者: ',yt.author)                # 影片作者
    print('作者頻道網址: ',yt.channel_url)   # 影片作者頻道網址
    print('縮圖網址: ',yt.thumbnail_url)     # 影片縮圖網址
    print('觀看數: ',yt.views)               # 影片觀看數

    # 分析
    #print(yt.streams)  # 影片支援哪些畫質
    print('stream數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def download_video_and_audio(url,itag_Vedio,itag_Audio):
    print('downdloading of video & audio .....')
    itag_List = [itag_Vedio,itag_Audio]
    for i in itag_List:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('downdload完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


#url = input("Enter the url of media : ")   
url='https://youtube.com/live/o6HQepxxDlo'   # 2023_11_10_下午
yt = YouTube(url) 
itag_Audio = 140
itag_Vedio = 137 
media_contents(url)
download_video_and_audio(url,itag_Vedio,itag_Audio)
merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag(merge).mp4')

os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4')
os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4')
print('合併成功！影像&音訊檔案刪除完成')

#<2023_11_10_下午> media 長度 03:10:30 容量大小731,905KB 處理耗時10m 6.4s
# Out:
# 標題:  2023_11_10_下午
# 長度 ( 秒 ):  10055
# 作者:  徐國堂
# 作者頻道網址:  https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址:  https://i.ytimg.com/vi/o6HQepxxDlo/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDfukQ0xJCh4CLKvLbNK4aegmeIQg
# 觀看數:  30
# stream數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_11_10_下午_itag(137)完成
# python_2023_11_10_下午_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_11_10_下午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_11_10_下午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_11_10_下午_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_11_10_下午_itag(merge).mp4
# 合併成功！影像&音訊檔案刪除完成

# %% [markdown]
# ========================================================================================
# ##### 以下為get_audio_only相關
# V0.7~ pass --> timeout for downloading
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ##### <參考>
# \w 匹配字母、數字和下劃線，即 [a-zA-Z0-9_]
# \u4e00-\u9fff 匹配 Unicode 范圍內的中文字符
# [\w\u4e00-\u9fff]+ 匹配一個或多個中英文字符
# 如果你想要更精確地匹配，可能需要根據實際需求進行調整。例如，如果你只想匹配中英文字符而不包括數字，可以使用 [a-zA-Z\u4e00-\u9fff]+。
#
# 更多示例
# 只匹配中英文字符（不包括數字和下劃線）：
# #### >>>pattern = r'[a-zA-Z\u4e00-\u9fff]+'
#
# 匹配中英文字符及空格（允許空格分隔的詞組）：
# #### >>>pattern = r'[a-zA-Z\u4e00-\u9fff\s]+'
#
# 匹配中英文字符及標點符號：
# #### >>>pattern = r'[a-zA-Z\u4e00-\u9fff.,!?，。！？]+'
#
# 使用這些模式可以靈活匹配各種包含中英文字符的字符串。根據具體需求選擇合適的正則表達式模式。

# %% [markdown]
# ---
# ---
# ### **V0.4.1 --> 修訂中**(2024.07.18~)

# %%
from pytube import YouTube

url='https://www.youtube.com/live/o6HQepxxDlo'   # 2023_11_10_下午
yt = YouTube(url)
print(f'標題: {yt.title}')              # 影片標題
print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
print(f'作者: {yt.author}')             # 影片作者
print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
print(f'觀看數: {yt.views}')            # 影片觀看數

# 分析
print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
print('影片支援畫質數: ',len(yt.streams))

for st in yt.streams:
    print(st)
print('media格式分析完成')
# Out:
# 標題: 2023_11_10_下午
# 長度(s): 10055
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/o6HQepxxDlo/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDfukQ0xJCh4CLKvLbNK4aegmeIQg
# 觀看數: 30
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 13
#      10 print(f'觀看數: {yt.views}')            # 影片觀看數
#      12 # 分析
# ---> 13 print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
#      14 print('影片支援畫質數: ',len(yt.streams))
#      16 for st in yt.streams:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:160, in YouTube.streaming_data(self)
#     158     return self.vid_info['streamingData']
#     159 else:
# --> 160     self.bypass_age_gate()
#     161     return self.vid_info['streamingData']
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:257, in YouTube.bypass_age_gate(self)
#     251 """Attempt to update the vid_info by bypassing the age gate."""
#     252 innertube = InnerTube(
#     253     client='ANDROID_EMBED',
#     254     use_oauth=self.use_oauth,
#     255     allow_cache=self.allow_oauth_cache
#     256 )
# --> 257 innertube_response = innertube.player(self.video_id)
#     259 playability_status = innertube_response['playabilityStatus'].get('status', None)
#     261 # If we still can't access the video, raise an exception
#     262 # (tier 3 age restriction)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\innertube.py:448, in InnerTube.player(self, video_id)
#     444 query = {
#     445     'videoId': video_id,
#     446 }
#     447 query.update(self.base_params)
# --> 448 return self._call_api(endpoint, query, self.base_data)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\innertube.py:390, in InnerTube._call_api(self, endpoint, query, data)
#     386         headers['Authorization'] = f'Bearer {self.access_token}'
#     388 headers.update(self.header)
# --> 390 response = request._execute_request(
#     391     endpoint_url,
#     392     'POST',
#     393     headers=headers,
#     394     data=data
#     395 )
#     396 return json.loads(response.read())
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File C:\python3.10.8\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\python3.10.8\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File C:\python3.10.8\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File C:\python3.10.8\lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File C:\python3.10.8\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File C:\python3.10.8\lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request

# %%
# V0.4.1 --> pass  (for window file rule)
# Base V0.4.0 -->完成 (2024.06.15止-->final)
## (for window file rule) list=['/',':','"','<','>','\?','\*'] # window檔案格式排除符號 --> pass

from pytube import YouTube
import subprocess
import os
import re

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def download_video_and_audio(url,itag_Vedio,itag_Audio):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*'] # window檔案格式排除符號
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱(檔名) : ',yt_title)

    print('downdloading of video & audio .....')
    itag_List = [itag_Vedio,itag_Audio]
    for i in itag_List:
        stream = yt.streams.get_by_itag(i)
        #stream.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('downdload完成')
    return yt_title

def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        #result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


#url = input("Enter the url of media : ")   
url='https://youtube.com/live/o6HQepxxDlo'   # 2023_11_10_下午
yt = YouTube(url) 
itag_Audio = 140
itag_Vedio = 137 
media_contents(url)
download_video_and_audio(url,itag_Vedio,itag_Audio)
merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag(merge).mp4')

#os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4')
#os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4')
print('合併成功！影像&音訊檔案刪除完成')

#<2023_11_10_下午> media 長度 03:10:30 容量大小731,905KB 處理耗時10m 6.4s
# Out:
# 標題: 2023_11_10_下午
# 長度(s): 10055
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/o6HQepxxDlo/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDfukQ0xJCh4CLKvLbNK4aegmeIQg
# 觀看數: 30
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 85
#      83 itag_Audio = 140
#      84 itag_Vedio = 137
# ---> 85 media_contents(url)
#      86 download_video_and_audio(url,itag_Vedio,itag_Audio)
#      87 merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag(merge).mp4')
#
# Cell In[1], line 19, in media_contents(url)
#      16 print(f'觀看數: {yt.views}')            # 影片觀看數
#      18 # 分析
# ---> 19 print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
#      20 print('影片支援畫質數: ',len(yt.streams))
#      22 for st in yt.streams:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:160, in YouTube.streaming_data(self)
#     158     return self.vid_info['streamingData']
#     159 else:
# --> 160     self.bypass_age_gate()
#     161     return self.vid_info['streamingData']
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:257, in YouTube.bypass_age_gate(self)
#     251 """Attempt to update the vid_info by bypassing the age gate."""
#     252 innertube = InnerTube(
#     253     client='ANDROID_EMBED',
#     254     use_oauth=self.use_oauth,
#     255     allow_cache=self.allow_oauth_cache
#     256 )
# --> 257 innertube_response = innertube.player(self.video_id)
#     259 playability_status = innertube_response['playabilityStatus'].get('status', None)
#     261 # If we still can't access the video, raise an exception
#     262 # (tier 3 age restriction)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\innertube.py:448, in InnerTube.player(self, video_id)
#     444 query = {
#     445     'videoId': video_id,
#     446 }
#     447 query.update(self.base_params)
# --> 448 return self._call_api(endpoint, query, self.base_data)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\innertube.py:390, in InnerTube._call_api(self, endpoint, query, data)
#     386         headers['Authorization'] = f'Bearer {self.access_token}'
#     388 headers.update(self.header)
# --> 390 response = request._execute_request(
#     391     endpoint_url,
#     392     'POST',
#     393     headers=headers,
#     394     data=data
#     395 )
#     396 return json.loads(response.read())
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File C:\python3.10.8\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\python3.10.8\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File C:\python3.10.8\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File C:\python3.10.8\lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File C:\python3.10.8\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File C:\python3.10.8\lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request

# %% [markdown]
# ### **V0.4.1 --> 修訂中**   ＾＾＾
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### **~單一網址(檔案)下載轉換**   ＾＾＾
# ---
# ---
# #### **複數網址(檔案)下載轉換 --> V0.5~**
# 文字檔 : filename.txt

# %%
import os
from pytube import YouTube

os.chdir('c:\youtube')
f = open('web_lists.txt','r')
web_list = f.readlines()
f.close()

for url in web_list:
    yt=YouTube(url)
    print(f'{url}標題: {yt.title}')
# Out:
# https://youtube.com/live/K1Y4dWk9eiI
# 標題: 2023_09_07_上午
# https://youtube.com/live/d0I8BGuU8Nk
# 標題: 2023_09_07_下午
# https://youtube.com/live/8g47p3taMgs
# 標題: 2023_09_11_早上

# %%
# V0.5 --> Base V0.4.0
## f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行2檔案下載合併程序之資料庫

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def download_video_and_audio(url,itag_Vedio,itag_Audio):
    print('downdloading of video & audio .....')
    itag_List = [itag_Vedio,itag_Audio]
    for i in itag_List:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('downdload完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


f = open('web_lists.txt','r')  # file_path 未明確定義 --> pass
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 
    media_contents(url)
    download_video_and_audio(url,itag_Vedio,itag_Audio)
    merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag(merge).mp4')

    os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4')
    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')

#<2023_09_07_上午> media 長度 02:36:10 容量大小397,946KB 
#<2023_09_07_下午> media 長度 02:55:29 容量大小545,131KB 
# 處理耗時共計9m 18.4s
# Out:
# ['https://youtube.com/live/K1Y4dWk9eiI\n', 'https://youtube.com/live/d0I8BGuU8Nk\n']
# 標題: 2023_09_07_上午
# 長度(s): 9370
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/K1Y4dWk9eiI/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLASlXOqWq6hHe99_McjR9i3NvXQQw
# 觀看數: 163
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_09_07_上午_itag(137)完成
# python_2023_09_07_上午_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_09_07_上午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_09_07_上午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_09_07_上午_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_09_07_上午_itag(merge).mp4
# 2023_09_07_上午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_07_下午
# 長度(s): 10530
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/d0I8BGuU8Nk/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGMgZShQMA8=&rs=AOn4CLC0mBaQ45HVtx3vJQ6hrBpTu8a66Q
# 觀看數: 54
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_09_07_下午_itag(137)完成
# python_2023_09_07_下午_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_09_07_下午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_09_07_下午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_09_07_下午_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_09_07_下午_itag(merge).mp4
# 2023_09_07_下午合併成功！影像&音訊檔案刪除完成

# %%
import os
from pytube import YouTube

os.chdir('c:\youtube')
f = open('web_lists.txt','r')
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:  # url之間有空行時
    if url == '\n' :
        continue
    else:
        yt=YouTube(url)
        print(f'{url}標題: {yt.title}')

print(f'目前工作資料夾{os.getcwd()}')
# Out:
# ['https://youtube.com/live/8g47p3taMgs\n', '\n', 'https://youtube.com/live/AtroDSd5d_8\n', '\n', 'https://youtube.com/live/6OibmpoCpLI\n']
# https://youtube.com/live/8g47p3taMgs
# 標題: 2023_09_11_早上
# https://youtube.com/live/AtroDSd5d_8
# 標題: 2023_09_11_下午
# https://youtube.com/live/6OibmpoCpLI
# 標題: 2023_09_18_上午
# 目前工作資料夾c:\youtube

# %%
# Base V0.5.1 -->完成 (2024.07.15止-->final)
# V0.5.1 --> Base V0.5.0
## f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def download_video_and_audio(url,itag_Vedio,itag_Audio):
    print('downdloading of video & audio .....')
    itag_List = [itag_Vedio,itag_Audio]
    for i in itag_List:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('downdload完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


f = open('web_lists.txt','r')  # file_path 未明確定義 --> pass
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 
    media_contents(url)
    download_video_and_audio(url,itag_Vedio,itag_Audio)
    merge_video_and_audio(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4', f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag(merge).mp4')

    os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'C:/Users/Lu/Documents/youtube/python_{yt.title}_itag({itag_Audio}).mp4')
    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')

#<2023_09_11_上午> media 長度 03:04:25 容量大小534,140KB 
#<2023_09_11_下午> media 長度 02:50:05 容量大小489,573KB 
#<2023_09_18_上午> media 長度 04:29:50 容量大小845,053KB 
# 處理耗時共計16m 25.1s
# Out:
# ['https://youtube.com/live/8g47p3taMgs\n', 'https://youtube.com/live/AtroDSd5d_8\n', 'https://youtube.com/live/6OibmpoCpLI']
# 標題: 2023_09_11_早上
# 長度(s): 11065
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/8g47p3taMgs/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLBgwYdXywJkJ2vEL_GVol3zFwwg8A
# 觀看數: 68
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_09_11_早上_itag(137)完成
# python_2023_09_11_早上_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_09_11_早上_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_09_11_早上_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_09_11_早上_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_09_11_早上_itag(merge).mp4
# 2023_09_11_早上合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_11_下午
# 長度(s): 10205
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/AtroDSd5d_8/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLAM5RDEd_EztxMD9skRYzZm0wDn-g
# 觀看數: 66
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_09_11_下午_itag(137)完成
# python_2023_09_11_下午_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_09_11_下午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_09_11_下午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_09_11_下午_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_09_11_下午_itag(merge).mp4
# 2023_09_11_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_18_上午
# 長度(s): 16190
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/6OibmpoCpLI/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDJ3Ap3I84jYnuqXc1mW8RnrAz9Mg
# 觀看數: 23
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_09_18_上午_itag(137)完成
# python_2023_09_18_上午_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i C:/Users/Lu/Documents/youtube/python_2023_09_18_上午_itag(137).mp4 -i C:/Users/Lu/Documents/youtube/python_2023_09_18_上午_itag(140).mp4 -c copy -map 0:v -map 1:a C:/Users/Lu/Documents/youtube/python_2023_09_18_上午_itag(merge).mp4
# 合併成功！輸出文件位於: C:/Users/Lu/Documents/youtube/python_2023_09_18_上午_itag(merge).mp4
# 2023_09_18_上午合併成功！影像&音訊檔案刪除完成

# %% [markdown]
# ---
# ---

# %%
#  note   (Base V0.5.1 -->完成 (2024.07.15止-->final))
# V0.6.0 --> Base V0.5.1
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
##  file_path 追加 & 簡化
## 調整 os.chdir(f'{output_path}')執行時序

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def download_video_and_audio(url,itag_Vedio,itag_Audio):
    print('downdloading of video & audio .....')
    itag_List = [itag_Vedio,itag_Audio]
    for i in itag_List:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('downdload完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 未明確定義 --> pass
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(url,itag_Vedio,itag_Audio)
    merge_video_and_audio(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4', f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4', f'{output_path}/python_{yt.title}_itag(merged).mp4')

    os.remove(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4')
    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')

#<2023_09_11_上午> media 長度 03:04:25 容量大小534,140KB 
#<2023_09_11_下午> media 長度 02:50:05 容量大小489,573KB 
#<2023_09_18_上午> media 長度 04:29:50 容量大小845,053KB 

#<2023_09_18_下午> media 長度 03:10:49 容量大小549,411KB 
# 處理耗時共計5m 7.7s
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/python
# 資料夾 c:/Users/Lu/Documents/youtube/python existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube/python
# 目前資料夾c:\Users\Lu\Documents\youtube\python
# ['https://youtube.com/live/r2KDWlgAK6g']
# 標題: 2023_09_18_下午
# 長度(s): 11450
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/r2KDWlgAK6g/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgVShIMA8=&rs=AOn4CLCYoz9lsOpEc2aQHQpnFW7IRCqliA
# 觀看數: 29
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_09_18_下午_itag(137)完成
# python_2023_09_18_下午_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i c:/Users/Lu/Documents/youtube/python/python_2023_09_18_下午_itag(137).mp4 -i c:/Users/Lu/Documents/youtube/python/python_2023_09_18_下午_itag(140).mp4 -c copy -map 0:v -map 1:a c:/Users/Lu/Documents/youtube/python/python_2023_09_18_下午_itag(merged).mp4
# 合併成功！輸出文件位於: c:/Users/Lu/Documents/youtube/python/python_2023_09_18_下午_itag(merged).mp4
# 2023_09_18_下午合併成功！影像&音訊檔案刪除完成

# %%
#  note   (Base V0.5.1 -->完成 (2024.07.15止-->final))
# V0.6.1 --> Base V0.6.0
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
#  file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序
## 工作資料夾設定後 -->程式path去重覆
## itag_List --> itag_list

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def download_video_and_audio(url,itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(url,itag_Vedio,itag_Audio)
    # merge_video_and_audio(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4', f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4', f'{output_path}/python_{yt.title}_itag(merged).mp4')
    #o s.remove(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4')
    # os.remove(f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4')

    merge_video_and_audio(f'python_{yt.title}_itag({itag_Vedio}).mp4', f'python_{yt.title}_itag({itag_Audio}).mp4', f'python_{yt.title}_itag(merged).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')
                          

    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')

#<2023_09_11_上午> media 長度 03:04:25 容量大小534,140KB 
#<2023_09_11_下午> media 長度 02:50:05 容量大小489,573KB 
#<2023_09_18_上午> media 長度 04:29:50 容量大小845,053KB 
#<2023_09_18_下午> media 長度 03:10:49 容量大小549,411KB 處理耗時共計5m 7.7s

#<2023_09_20_上午> media 長度 03:21:00 容量大小585,071KB 

# 處理耗時共計6m 51.6s
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/python
# 資料夾 c:/Users/Lu/Documents/youtube/python existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube/python
# 目前資料夾c:\Users\Lu\Documents\youtube\python
# ['https://youtube.com/live/hMt-dGJ56nY']
# 標題: 2023_09_20_早上
# 長度(s): 12060
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/hMt-dGJ56nY/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLBrgCJZeGHTb-s3lSPOJb2wJh_p_A
# 觀看數: 38
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downdloading of video & audio .....
# python_2023_09_20_早上_itag(137)完成
# python_2023_09_20_早上_itag(140)完成
# downdload完成
# 執行merge命令: ffmpeg -i python_2023_09_20_早上_itag(137).mp4 -i python_2023_09_20_早上_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_20_早上_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_20_早上_itag(merged).mp4
# 2023_09_20_早上合併成功！影像&音訊檔案刪除完成

# %%
# Base V0.6.2 -->完成 (2024.07.16止-->final))
# V0.6.2 --> Base V0.6.1
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
#  file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序
# 工作資料夾設定後 -->程式path去重覆
# itag_List --> itag_list
## def download_video_and_audio(url,itag_Vedio,itag_Audio): -->def download_video_and_audio(itag_Vedio,itag_Audio):

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


## def download_video_and_audio(url,itag_Vedio,itag_Audio):
def download_video_and_audio(itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(itag_Vedio,itag_Audio)
    # download_video_and_audio(url,itag_Vedio,itag_Audio)
    # merge_video_and_audio(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4', f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4', f'{output_path}/python_{yt.title}_itag(merged).mp4')
    #o s.remove(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4')
    # os.remove(f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4')

    merge_video_and_audio(f'python_{yt.title}_itag({itag_Vedio}).mp4', f'python_{yt.title}_itag({itag_Audio}).mp4', f'python_{yt.title}_itag(merged).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')
                          

    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')

#<2023_09_11_上午> media 長度 03:04:25 容量大小534,140KB 
#<2023_09_11_下午> media 長度 02:50:05 容量大小489,573KB 
#<2023_09_18_上午> media 長度 04:29:50 容量大小845,053KB 
#<2023_09_18_下午> media 長度 03:10:49 容量大小549,411KB 處理耗時共計5m 7.7s
#<2023_09_20_上午> media 長度 03:21:00 容量大小585,071KB 處理耗時共計6m 51.6s

#<2023_09_20_下午> media 長度 02:45:55 容量大小442,607KB 
#<2023_09_22_上午> media 長度 03:13:15 容量大小577,610KB 
#<2023_09_22_下午> media 長度 03:02:00 容量大小490,263KB 
# 處理耗時共計24m 56.9s
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/python
# 資料夾 c:/Users/Lu/Documents/youtube/python existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube/python
# 目前資料夾c:\Users\Lu\Documents\youtube\python
# ['https://youtube.com/live/BgyVjoaILBs\n', 'https://youtube.com/live/iRUhnaOosrg\n', 'https://youtube.com/live/0Hwl5hai3uM']
# 標題: 2023_09_20_下午
# 長度(s): 9955
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/BgyVjoaILBs/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGEggXChlMA8=&rs=AOn4CLAjdZriy5AXWW_rxcBPnVh7oyYz8Q
# 觀看數: 40
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_09_20_下午_itag(137)完成
# python_2023_09_20_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_09_20_下午_itag(137).mp4 -i python_2023_09_20_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_20_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_20_下午_itag(merged).mp4
# 2023_09_20_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_22_上午
# 長度(s): 11595
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/iRUhnaOosrg/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDgu1iN__SRDnW6gjipgFjcGp53QQ
# 觀看數: 22
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_09_22_上午_itag(137)完成
# python_2023_09_22_上午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_09_22_上午_itag(137).mp4 -i python_2023_09_22_上午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_22_上午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_22_上午_itag(merged).mp4
# 2023_09_22_上午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_22_下午
# 長度(s): 10920
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/0Hwl5hai3uM/hq720.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgXChHMA8=&rs=AOn4CLC37o76gW2NLLcxbpWlB_5Fxb4i3Q
# 觀看數: 20
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  8
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_09_22_下午_itag(137)完成
# python_2023_09_22_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_09_22_下午_itag(137).mp4 -i python_2023_09_22_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_22_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_22_下午_itag(merged).mp4
# 2023_09_22_下午合併成功！影像&音訊檔案刪除完成

# %%
# issue for HTTP Error 400_Bad Request of pytube

# 使用模組
from pytube import YouTube
from pytube. innertube import _default_clients

_default_clients[ "ANDROID"][ "context"]["client"]["clientVersion"] = "19.08.35"
_default_clients["IOS"]["context"]["client"]["clientVersion"] = "19.08.35"
_default_clients[ "ANDROID_EMBED"][ "context"][ "client"]["clientVersion"] = "19.08.35"
_default_clients[ "IOS_EMBED"][ "context"]["client"]["clientVersion"] = "19.08.35"
_default_clients["IOS_MUSIC"][ "context"]["client"]["clientVersion"] = "6.41"
_default_clients[ "ANDROID_MUSIC"] = _default_clients[ "ANDROID_CREATOR" ]

# %%
# Base V0.6.2 -->完成 (2024.07.16止-->final))
# V0.6.2 --> test


from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    # print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    # print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    # print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    # print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


## def download_video_and_audio(url,itag_Vedio,itag_Audio):
def download_video_and_audio(itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(itag_Vedio,itag_Audio)
    merge_video_and_audio(f'python_{yt.title}_itag({itag_Vedio}).mp4', f'python_{yt.title}_itag({itag_Audio}).mp4', f'python_{yt.title}_itag(merged).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')
                          

    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')

#<2023_09_11_上午> media 長度 03:04:25 容量大小534,140KB 
#<2023_09_11_下午> media 長度 02:50:05 容量大小489,573KB 
#<2023_09_18_上午> media 長度 04:29:50 容量大小845,053KB 
#<2023_09_18_下午> media 長度 03:10:49 容量大小549,411KB 處理耗時共計5m 7.7s
#<2023_09_20_上午> media 長度 03:21:00 容量大小585,071KB 處理耗時共計6m 51.6s

#<2023_09_20_下午> media 長度 02:45:55 容量大小442,607KB 
#<2023_09_22_上午> media 長度 03:13:15 容量大小577,610KB 
#<2023_09_22_下午> media 長度 03:02:00 容量大小490,263KB 
# 處理耗時共計24m 56.9s

#<2023_09_26_上午> media 長度 02:59:40 容量大小482,009KB 
#<2023_09_26_下午> media 長度 03:09:40 容量大小578,695KB 
#<2023_09_28_上午> media 長度 02:50:24 容量大小512,415KB 
#<2023_09_28_下午> media 長度 02:45:05 容量大小581,510KB 
# 處理耗時共計20m 4.1s
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/python
# 資料夾 c:/Users/Lu/Documents/youtube/python existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube/python
# 目前資料夾c:\Users\Lu\Documents\youtube\python
# ['https://youtube.com/live/4J4UWmFHp1s\n', 'https://youtube.com/live/FgTKl1i6bXE\n', 'https://youtube.com/live/uVgkjUgoAzM\n', 'https://youtube.com/live/3J14_89QTN4']
# 標題: 2023_09_26_早上
# 長度(s): 11360
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/4J4UWmFHp1s/sddefault.jpg?sqp=-oaymwEmCIAFEOAD8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGFogZShZMA8=&rs=AOn4CLDgW5WUmnJJLPtivYNHEFtx7n1stw
# 觀看數: 28
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  7
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_09_26_早上_itag(137)完成
# python_2023_09_26_早上_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_09_26_早上_itag(137).mp4 -i python_2023_09_26_早上_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_26_早上_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_26_早上_itag(merged).mp4
# 2023_09_26_早上合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_26_下午
# 長度(s): 10780
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/FgTKl1i6bXE/sddefault.jpg?sqp=-oaymwEmCIAFEOAD8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgVyhAMA8=&rs=AOn4CLCZA5Y-CmTCSsOUqG-SwXQ2UNFqyw
# 觀看數: 36
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  7
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_09_26_下午_itag(137)完成
# python_2023_09_26_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_09_26_下午_itag(137).mp4 -i python_2023_09_26_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_26_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_26_下午_itag(merged).mp4
# 2023_09_26_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_28_上午
# 長度(s): 10240
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/uVgkjUgoAzM/sddefault.jpg?sqp=-oaymwEmCIAFEOAD8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLAULaFdVJWTZAP3I5eMyeEvbmP-YQ
# 觀看數: 33
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  7
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_09_28_上午_itag(137)完成
# python_2023_09_28_上午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_09_28_上午_itag(137).mp4 -i python_2023_09_28_上午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_28_上午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_28_上午_itag(merged).mp4
# 2023_09_28_上午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_09_28_下午
# 長度(s): 9905
# 作者: 徐國堂
# 網址: https://www.youtube.com/channel/UCKd_tuM8M79b1GAwAlTi9ZA
# 縮圖網址: https://i.ytimg.com/vi/3J14_89QTN4/sddefault.jpg?sqp=-oaymwEmCIAFEOAD8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGBYgTCh_MA8=&rs=AOn4CLBDbzQRdqbMUGlQ2DlBRhvTNnbuDA
# 觀看數: 30
# 支援畫質:[<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]
# 影片支援畫質數:  7
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_09_28_下午_itag(137)完成
# python_2023_09_28_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_09_28_下午_itag(137).mp4 -i python_2023_09_28_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_09_28_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_09_28_下午_itag(merged).mp4
# 2023_09_28_下午合併成功！影像&音訊檔案刪除完成

# %%
# V0.6.3
# Base V0.6.2 -->完成 (2024.07.16止-->final))
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
#  file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序
# 工作資料夾設定後 -->程式path去重覆
# itag_List --> itag_list
# def download_video_and_audio(url,itag_Vedio,itag_Audio): -->def download_video_and_audio(itag_Vedio,itag_Audio):
## remove "\n" by using the replace() method in list when reads each line of text from our text file

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    # print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    # print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    # print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    # print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    # print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


## def download_video_and_audio(url,itag_Vedio,itag_Audio):
def download_video_and_audio(itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
web_list = f.readlines()
print(web_list)
f.close()

for i in web_list:
    url = i.replace("\n", "")    # remove "\n"
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(itag_Vedio,itag_Audio)
    # download_video_and_audio(url,itag_Vedio,itag_Audio)
    # merge_video_and_audio(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4', f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4', f'{output_path}/python_{yt.title}_itag(merged).mp4')
    #o s.remove(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4')
    # os.remove(f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4')

    merge_video_and_audio(f'python_{yt.title}_itag({itag_Vedio}).mp4', f'python_{yt.title}_itag({itag_Audio}).mp4', f'python_{yt.title}_itag(merged).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')
                          

    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')

#<2023_09_11_上午> media 長度 03:04:25 容量大小534,140KB 
#<2023_09_11_下午> media 長度 02:50:05 容量大小489,573KB 
#<2023_09_18_上午> media 長度 04:29:50 容量大小845,053KB 
#<2023_09_18_下午> media 長度 03:10:49 容量大小549,411KB 處理耗時共計5m 7.7s
#<2023_09_20_上午> media 長度 03:21:00 容量大小585,071KB 處理耗時共計6m 51.6s

#<2023_09_20_下午> media 長度 02:45:55 容量大小442,607KB 
#<2023_09_22_上午> media 長度 03:13:15 容量大小577,610KB 
#<2023_09_22_下午> media 長度 03:02:00 容量大小490,263KB 
# 處理耗時共計24m 56.9s

#<2023_09_26_上午> media 長度 02:59:40 容量大小482,009KB 
#<2023_09_26_下午> media 長度 03:09:40 容量大小578,695KB 
#<2023_09_28_上午> media 長度 02:50:24 容量大小512,415KB 
#<2023_09_28_下午> media 長度 02:45:05 容量大小581,510KB 
# 處理耗時共計20m 4.1s

#<2023_10_03_上午> media 長度 02:57:45 容量大小568,120KB 
#<2023_10_03_下午> media 長度 03:05:15 容量大小655,650KB 
# 處理耗時共計11m 28.0s

#<2023_10_05_上午> media 長度 04:24:34 容量大小818,273KB 
#<2023_10_05_下午> media 長度 03:16:15 容量大小710,979KB
#<2023_10_11_上午1> media 長度 01:02:45 容量大小170,727KB 
#<2023_10_11_上午2> media 長度 01:00:45 容量大小232,327KB
#<2023_10_11_下午> media 長度 03:05:50 容量大小690,715KB
#<2023_10_12_上午> media 長度 03:19:35 容量大小692,957KB
#<2023_10_12_下午> media 長度 03:05:05 容量大小902,193KB
#<2023_10_12_上午> media 長度 03:19:35 容量大小692,957KB
#<2023_10_12_下午> media 長度 03:05:05 容量大小902,193KB
#<2023_10_16_上午> media 長度 03:04:25 容量大小699,754KB
#<2023_10_16_下午> media 長度 03:00:35 容量大小929,460KB
# 處理耗時共計51m 4.2s

#<2023_10_18_上午> media 長度 03:54:50 容量大小870,976KB
#<2023_10_18_下午> media 長度 02:50:35 容量大小737,507KB
#<2023_10_26_上午> media 長度 03:14:12 容量大小747,948KB
#<2023_10_26_下午1> media 長度 00:21:10 容量大小130,039KB
#<2023_10_26_下午2> media 長度 0x:xx:xx 容量大小xxx,xxxKB(檔名重複_逾時3s)
#<2023_11_01_上午> media 長度 03:49:09 容量大小839,718KB
#<2023_11_01_下午> media 長度 02:47:20 容量大小663,567KB
#<2023_11_02_上午> media 長度 03:08:29 容量大小884,584KB
#<2023_11_02_下午> media 長度 02:58:40 容量大小747,267KB
#<2023_11_08_上午> media 長度 03:07:45 容量大小597,265KB
#<2023_11_08_下午> media 長度 02:57:30 容量大小715,014KB
# 處理耗時共計65m 30.6s
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/python
# 資料夾 c:/Users/Lu/Documents/youtube/python existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube/python
# 目前資料夾c:\Users\Lu\Documents\youtube\python
# ['https://youtube.com/live/AaEnG156Dz4\n', 'https://youtube.com/live/ZJ0Ug6ZZbDY\n', 'https://youtube.com/live/y4Q9VwB2O6A\n', 'https://youtube.com/live/O4-xNNJmaQ8\n', 'https://youtube.com/live/iOCZOlfb3Sg\n', 'https://youtube.com/live/wJhn4V0tMqM\n', 'https://youtube.com/live/bo7vnbr8KEw\n', 'https://youtube.com/live/2MpWKit3ynA\n', 'https://youtube.com/live/daEfGFzEJ78\n', 'https://youtube.com/live/QK78Q5iEhbg\n', 'https://youtube.com/live/UjwZ3OwG1y0']
# 標題: 2023_10_18_早上
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_10_18_早上_itag(137)完成
# python_2023_10_18_早上_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_10_18_早上_itag(137).mp4 -i python_2023_10_18_早上_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_10_18_早上_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_10_18_早上_itag(merged).mp4
# 2023_10_18_早上合併成功！影像&音訊檔案刪除完成
# 標題: 2023_10_18_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_10_18_下午_itag(137)完成
# python_2023_10_18_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_10_18_下午_itag(137).mp4 -i python_2023_10_18_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_10_18_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_10_18_下午_itag(merged).mp4
# 2023_10_18_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_10_26_早上
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_10_26_早上_itag(137)完成
# python_2023_10_26_早上_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_10_26_早上_itag(137).mp4 -i python_2023_10_26_早上_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_10_26_早上_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_10_26_早上_itag(merged).mp4
# 2023_10_26_早上合併成功！影像&音訊檔案刪除完成
# 標題: 2023_10_26_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_10_26_下午_itag(137)完成
# python_2023_10_26_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_10_26_下午_itag(137).mp4 -i python_2023_10_26_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_10_26_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_10_26_下午_itag(merged).mp4
# 2023_10_26_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_10_26_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_10_26_下午_itag(137)完成
# python_2023_10_26_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_10_26_下午_itag(137).mp4 -i python_2023_10_26_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_10_26_下午_itag(merged).mp4
# 命令執行超時: Command '['ffmpeg', '-i', 'python_2023_10_26_下午_itag(137).mp4', '-i', 'python_2023_10_26_下午_itag(140).mp4', '-c', 'copy', '-map', '0:v', '-map', '1:a', 'python_2023_10_26_下午_itag(merged).mp4']' timed out after 30 seconds
# 2023_10_26_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_11_01_上午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_11_01_上午_itag(137)完成
# python_2023_11_01_上午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_11_01_上午_itag(137).mp4 -i python_2023_11_01_上午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_11_01_上午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_11_01_上午_itag(merged).mp4
# 2023_11_01_上午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_11_01_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_11_01_下午_itag(137)完成
# python_2023_11_01_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_11_01_下午_itag(137).mp4 -i python_2023_11_01_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_11_01_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_11_01_下午_itag(merged).mp4
# 2023_11_01_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_11_02_早上
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_11_02_早上_itag(137)完成
# python_2023_11_02_早上_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_11_02_早上_itag(137).mp4 -i python_2023_11_02_早上_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_11_02_早上_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_11_02_早上_itag(merged).mp4
# 2023_11_02_早上合併成功！影像&音訊檔案刪除完成
# 標題: 2023_11_02_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_11_02_下午_itag(137)完成
# python_2023_11_02_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_11_02_下午_itag(137).mp4 -i python_2023_11_02_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_11_02_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_11_02_下午_itag(merged).mp4
# 2023_11_02_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_11_08_上午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_11_08_上午_itag(137)完成
# python_2023_11_08_上午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_11_08_上午_itag(137).mp4 -i python_2023_11_08_上午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_11_08_上午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_11_08_上午_itag(merged).mp4
# 2023_11_08_上午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_11_08_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_11_08_下午_itag(137)完成
# python_2023_11_08_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_11_08_下午_itag(137).mp4 -i python_2023_11_08_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_11_08_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_11_08_下午_itag(merged).mp4
# 2023_11_08_下午合併成功！影像&音訊檔案刪除完成

# %%
# V0.6.4 --> Base V0.6.3
# note V0.6.2 -->完成 (2024.07.16止-->final))
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
#  file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序
# 工作資料夾設定後 -->程式path去重覆
# itag_List --> itag_list
# def download_video_and_audio(url,itag_Vedio,itag_Audio): -->def download_video_and_audio(itag_Vedio,itag_Audio):
# remove "\n" by using the replace() method in list when reads each line of text from our text file
## 檔名重複_逾時30s,未merge video_audio,既刪除video & audio檔案

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    # print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    # print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    # print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    # print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    # print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    # print(f'預設檔案位置 {output_path}')
    print(f'目前工作資料夾{os.getcwd()}') 


## def download_video_and_audio(url,itag_Vedio,itag_Audio):
def download_video_and_audio(itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
        os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
        os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')
        print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
web_list = f.readlines()
print(web_list)
f.close()

for i in web_list:
    url = i.replace("\n", "")    # remove "\n"
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(itag_Vedio,itag_Audio)
    # download_video_and_audio(url,itag_Vedio,itag_Audio)
    # merge_video_and_audio(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4', f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4', f'{output_path}/python_{yt.title}_itag(merged).mp4')
    #o s.remove(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4')
    # os.remove(f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4')

    merge_video_and_audio(f'python_{yt.title}_itag({itag_Vedio}).mp4', f'python_{yt.title}_itag({itag_Audio}).mp4', f'python_{yt.title}_itag(merged).mp4')
    # os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
    # os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')                          
    # print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')


#<2023_10_26_下午2> media 長度 0x:xx:xx 容量大小xxx,xxxKB(檔名重複_逾時30s) -->
#<2023_10_26_下午2> media 長度 02:19:40 容量大小454,728KB
# 處理耗時共計65m 30.6s
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/python
# 資料夾 c:/Users/Lu/Documents/youtube/python existed
# 預設檔案位置 c:/Users/Lu/Documents/youtube/python
# 目前資料夾c:\Users\Lu\Documents\youtube\python
# ['https://youtube.com/live/iOCZOlfb3Sg\n']
# 標題: 2023_10_26_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_10_26_下午_itag(137)完成
# python_2023_10_26_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_10_26_下午_itag(137).mp4 -i python_2023_10_26_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_10_26_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_10_26_下午_itag(merged).mp4
# 2023_10_26_下午合併成功！影像&音訊檔案刪除完成

# %%
# issue for HTTP Error 400_Bad Request of pytube
# https://github.com/pytube/pytube/issues/1973  
# issue date:2024.07.17 

# 使用模組
from pytube import YouTube
from pytube. innertube import _default_clients

_default_clients[ "ANDROID"][ "context"]["client"]["clientVersion"] = "19.08.35"
_default_clients["IOS"]["context"]["client"]["clientVersion"] = "19.08.35"
_default_clients[ "ANDROID_EMBED"][ "context"][ "client"]["clientVersion"] = "19.08.35"
_default_clients[ "IOS_EMBED"][ "context"]["client"]["clientVersion"] = "19.08.35"
_default_clients["IOS_MUSIC"][ "context"]["client"]["clientVersion"] = "6.41"
_default_clients[ "ANDROID_MUSIC"] = _default_clients[ "ANDROID_CREATOR" ]



yt = YouTube('https://youtube.com/live/vkFkSfAtCI0')

# 影片格式分析
print(f'標題: {yt.title}')              # 影片標題
# print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
print(f'作者: {yt.author}')             # 影片作者
# print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
# print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
# print(f'觀看數: {yt.views}')            # 影片觀看數

# 分析
# print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
# print('影片支援畫質數: ',len(yt.streams))

for st in yt.streams:
    print(st)
print('media格式分析完成')
# Out:
# 標題: 2023_12_04_早上
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成

# %%
# V0.6.4 --> Test OK  (Base V0.6.3)
# note V0.6.2 -->完成 (2024.07.16止-->final))
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
#  file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序
# 工作資料夾設定後 -->程式path去重覆
# itag_List --> itag_list
# def download_video_and_audio(url,itag_Vedio,itag_Audio): -->def download_video_and_audio(itag_Vedio,itag_Audio):
# remove "\n" by using the replace() method in list when reads each line of text from our text file
## 檔名重複_逾時30s,未merge video_audio,既刪除video & audio檔案

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    # print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    # print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    # print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    # print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    # print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    # print(f'預設檔案位置 {output_path}')
    print(f'目前工作資料夾{os.getcwd()}') 


## def download_video_and_audio(url,itag_Vedio,itag_Audio):
def download_video_and_audio(itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
        os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
        os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')
        print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
web_list = f.readlines()
print(web_list)
f.close()

for i in web_list:
    url = i.replace("\n", "")    # remove "\n"
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(itag_Vedio,itag_Audio)
    # download_video_and_audio(url,itag_Vedio,itag_Audio)
    # merge_video_and_audio(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4', f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4', f'{output_path}/python_{yt.title}_itag(merged).mp4')
    #o s.remove(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4')
    # os.remove(f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4')

    merge_video_and_audio(f'python_{yt.title}_itag({itag_Vedio}).mp4', f'python_{yt.title}_itag({itag_Audio}).mp4', f'python_{yt.title}_itag(merged).mp4')
    # os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
    # os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')                          
    # print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')


#<2023_10_26_下午2> media 長度 0x:xx:xx 容量大小xxx,xxxKB(檔名重複_逾時30s) -->
#<2023_10_26_下午2> media 長度 02:19:40 容量大小454,728KB

#<2023_12_04_上午> media 長度 03:44:20 容量大小762,850KB
#<2023_12_04_下午> media 長度 03:05:00 容量大小731,261KB
#<2023_12_06_上午> media 長度 03:11:00 容量大小720,183KB
#<2023_12_06_下午> media 長度 03:02:15 容量大小798,737KB
#<2023_12_11_上午> media 長度 02:59:55 容量大小772,163KB
#<2023_12_11_下午> media 長度 03:06:15 容量大小889,753KB
#<2023_12_13_上午> media 長度 03:22:45 容量大小836,906KB
#<2023_12_13_下午> media 長度 03:06:25 容量大小754,954KB
#<2023_12_13_上午> media 長度 03:22:45 容量大小836,906KB
#<2023_12_13_下午> media 長度 03:06:25 容量大小754,954KB
# 處理耗時共計62m 39.9s (2024.07.29)

#<2023_12_19_上午> media 長度 03:28:40 容量大小1,175,339KB
#<2023_12_19_下午> media 長度 02:59:50 容量大小711,324KB
#<2023_12_22_上午> media 長度 03:01:35 容量大小647,371KB
#<2023_12_22_下午> media 長度 03:14:30 容量大小742,764KB
# 處理耗時共計19m 19.2s (2024.07.29)
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/python
# 資料夾 c:/Users/Lu/Documents/youtube/python existed
# 目前工作資料夾c:\Users\Lu\Documents\youtube\python
# ['https://youtube.com/live/n7eicT5seJc\n', 'https://youtube.com/live/9EpGCqLymb0\n', 'https://youtube.com/live/CwXFGsBo5I4\n', 'https://youtube.com/live/stTMWa9c0rE']
# 標題: 2023_12_19_早上
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_12_19_早上_itag(137)完成
# python_2023_12_19_早上_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_12_19_早上_itag(137).mp4 -i python_2023_12_19_早上_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_12_19_早上_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_12_19_早上_itag(merged).mp4
# 2023_12_19_早上合併成功！影像&音訊檔案刪除完成
# 標題: 2023_12_19_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_12_19_下午_itag(137)完成
# python_2023_12_19_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_12_19_下午_itag(137).mp4 -i python_2023_12_19_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_12_19_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_12_19_下午_itag(merged).mp4
# 2023_12_19_下午合併成功！影像&音訊檔案刪除完成
# 標題: 2023_12_22_早上
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_12_22_早上_itag(137)完成
# python_2023_12_22_早上_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_12_22_早上_itag(137).mp4 -i python_2023_12_22_早上_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_12_22_早上_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_12_22_早上_itag(merged).mp4
# 2023_12_22_早上合併成功！影像&音訊檔案刪除完成
# 標題: 2023_12_22_下午
# 作者: 徐國堂
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">
# media格式分析完成
# downloading of video & audio .....
# python_2023_12_22_下午_itag(137)完成
# python_2023_12_22_下午_itag(140)完成
# download完成
# 執行merge命令: ffmpeg -i python_2023_12_22_下午_itag(137).mp4 -i python_2023_12_22_下午_itag(140).mp4 -c copy -map 0:v -map 1:a python_2023_12_22_下午_itag(merged).mp4
# 合併成功！輸出文件位於: python_2023_12_22_下午_itag(merged).mp4
# 2023_12_22_下午合併成功！影像&音訊檔案刪除完成

# %%
# V0.6.5 --> Base V0.6.4
# note V0.6.2 -->完成 (2024.07.16止-->final))
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
#  file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序
# 工作資料夾設定後 -->程式path去重覆
# itag_List --> itag_list
# def download_video_and_audio(url,itag_Vedio,itag_Audio): -->def download_video_and_audio(itag_Vedio,itag_Audio):
# remove "\n" by using the replace() method in list when reads each line of text from our text file
# 檔名重複_逾時30s,未merge video_audio,既刪除video & audio檔案
## 整合 def dir_path(output_path):  -->  def dir_path(dir_name):
## 修正 f = open('web_lists.txt','r') 無效時--> exception
## filename_prefix

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    # print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    # print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    # print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    # print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    # print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(dir_name):
    file_path = f'c:/{dir_name}/filename.ext'
    output_path = os.path.dirname(file_path)
    print(f'out_path >>> {output_path}')
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    # print(f'預設檔案位置 {output_path}')
    print(f'目前工作資料夾{os.getcwd()}') 
    return output_path


## def download_video_and_audio(url,itag_Vedio,itag_Audio):
def download_video_and_audio(itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'{filename_prefix}_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'{filename_prefix}_{yt.title}_itag({i})完成')
    print('video_and_audio download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=60)
        print("合併成功！輸出文件位於:", output_path)
        os.remove(f'{filename_prefix}_{yt.title}_itag({itag_Vedio}).mp4')
        os.remove(f'{filename_prefix}_{yt.title}_itag({itag_Audio}).mp4')
        print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)

dir_name = 'Users/Lu/Documents/youtube/openAPI'  # 設定工作/儲存檔案之資料夾
filename_prefix = 'openAPI'
# dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
## filename_prefix = 'python'
# file_path = f'c:/{dir_name}/filename.ext'
# output_path = os.path.dirname(file_path)
# print(f'out_path >>> {output_path}')
# dir_path(output_path)
output_path = dir_path(dir_name)

try :
    f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
    web_list = f.readlines()
    print(f'web_list : {web_list}')
    f.close()

    for i in web_list:
        url = i.replace("\n", "")    # remove "\n"
        yt = YouTube(url) 
        itag_Audio = 140
        itag_Vedio = 137 

        media_contents(url)
        download_video_and_audio(itag_Vedio,itag_Audio)
        # download_video_and_audio(url,itag_Vedio,itag_Audio)
        # merge_video_and_audio(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4', f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4', f'{output_path}/python_{yt.title}_itag(merged).mp4')
        #o s.remove(f'{output_path}/python_{yt.title}_itag({itag_Vedio}).mp4')
        # os.remove(f'{output_path}/python_{yt.title}_itag({itag_Audio}).mp4')

        merge_video_and_audio(f'{filename_prefix}_{yt.title}_itag({itag_Vedio}).mp4', f'{filename_prefix}_{yt.title}_itag({itag_Audio}).mp4', f'{filename_prefix}_{yt.title}_itag(merged).mp4')
        # os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
        # os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')                          
        # print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')
except FileNotFoundError as e:
    print("open錯誤_檔或目錄不存在:", e) 
    f = open('web_lists.txt','w')  # file_path 明確定義? --> ok
    print("建立網址文件檔案 : web_lists.txt") 
    f.close()
except OSError as e:
    print("過程中發生錯誤::", e) 



#<2023_10_26_下午2> media 長度 02:19:40 容量大小454,728KB
# 處理耗時共計65m 30.6s
# Out:
# out_path >>> c:/Users/Lu/Documents/youtube/openAPI
# 資料夾 c:/Users/Lu/Documents/youtube/openAPI existed
# 目前工作資料夾c:\Users\Lu\Documents\youtube\openAPI
# ['https://youtube.com/live/pMGfu6cHfvY\n', 'https://youtube.com/live/fPXDY3GVLQo']
# 標題: 2024_01_08_下午
# 作者: 徐國堂
# 過程中發生錯誤:: HTTP Error 400: Bad Request

# %% [markdown]
# ---
# ---

# %%
# V0.7.0 --> pass (for window file rule)
# V0.7.0 --> Base V0.6.2
# f = open('web_lists.txt','r') 以'web_lists.txt'作重覆執行多檔案下載合併程序之資料庫
#  file_path 追加 & 簡化
# 調整 os.chdir(f'{output_path}')執行時序
# 工作資料夾設定後 -->程式path去重覆
# itag_List --> itag_list
# def download_video_and_audio(url,itag_Vedio,itag_Audio): -->def download_video_and_audio(itag_Vedio,itag_Audio):
## list=['/',':','"','<','>','\?','\*'] # window檔案格式排除符號 --> pass

from pytube import YouTube
import subprocess
import os

def media_contents(url):
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)
    print('media格式分析完成')


def dir_path(output_path):
    try:
        os.chdir(f'{output_path}')  # 解決:os.mkdir如果目錄已經存在，FileExistsError則會引發 --> OK
        print(f'資料夾 {output_path} existed')
    except:
        #os.mkdir(f'{os.path.dirname(filepath)}')
        os.makedirs(f'{output_path}')
        print(f'建立新檔案資料夾 {output_path}')
        os.chdir(f'{output_path}')

    print(f'預設檔案位置 {output_path}')
    print(f'目前資料夾{os.getcwd()}') 


def download_video_and_audio(itag_Vedio,itag_Audio):
    print('downloading of video & audio .....')
    itag_list = [itag_Vedio,itag_Audio]
    for i in itag_list:
        stream = yt.streams.get_by_itag(i)
        stream.download(output_path=output_path,filename=f'python_{yt.title}_itag({i}).mp4', skip_existing=True, max_retries=0)
        print(f'python_{yt.title}_itag({i})完成')
    print('download完成')


def merge_video_and_audio(video_path, audio_path, output_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-i', audio_path,
        '-c', 'copy',
        '-map', '0:v',
        '-map', '1:a',
        output_path
    ]
    
    try:
        print("執行merge命令:", ' '.join(command))  # 增加執行內容訊息
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8',timeout=30)
        print("合併成功！輸出文件位於:", output_path)
    except subprocess.CalledProcessError as e:
        print("ffmpeg合併過程中發生錯誤:", e)
        if e.stderr:
            try:
                # 嘗試用 UTF-8 解碼
                print("ffmpeg命令輸出:", e.stderr)
            except UnicodeDecodeError:
                # 如果失敗，使用 CP950 解碼
                print("ffmpeg命令輸出:", e.stderr.decode(encoding='cp950', errors='ignore'))
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")
    except subprocess.TimeoutExpired as e:
        print("命令執行超時:", e)


dir_name = 'Users/Lu/Documents/youtube/python'  # 設定工作/儲存檔案之資料夾
file_path = f'c:/{dir_name}/filename.ext'
output_path = os.path.dirname(file_path)
print(f'out_path >>> {output_path}')
dir_path(output_path)

f = open('web_lists.txt','r')  # file_path 明確定義? --> ok
web_list = f.readlines()
print(web_list)
f.close()

for url in web_list:
    yt = YouTube(url) 
    itag_Audio = 140
    itag_Vedio = 137 

    media_contents(url)
    download_video_and_audio(itag_Vedio,itag_Audio)

    merge_video_and_audio(f'python_{yt.title}_itag({itag_Vedio}).mp4', f'python_{yt.title}_itag({itag_Audio}).mp4', f'python_{yt.title}_itag(merged).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Vedio}).mp4')
    os.remove(f'python_{yt.title}_itag({itag_Audio}).mp4')
                          

    print(f'{yt.title}合併成功！影像&音訊檔案刪除完成')
