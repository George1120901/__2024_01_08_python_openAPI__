# %% [markdown]
# V1.0之測試版

# %%
# V0.82 -->2024.06.22 ok
# get_audio_only V0.6 --> 2024.06.19 final
# 定義全局變量 global
# 設定包含中英文字及空格 r'[\w\u4e00-\u9fff\s]+'

from pytube import YouTube
import re
import subprocess

#url = input("Enter the url of media : ")   
#url = 'https://www.youtube.com/watch?v=VBNUwMd_eF4&t=4029s'  # 曲目:蕭邦 一定要聽的鋼琴古典樂 ｜放鬆音樂 讀書 專注 The Best "Chopin" Classical Piano Music｜Relaxing Studying Music

# 定義全局變量
global_yt_title = None

def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ \u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)
    global global_yt_title   # 定義全局變量
    global_yt_title = yt_title    # 定義全局變量

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)   #執行ok
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '3',
        output_file
    ]
    # -q:a 3 大約是 160 kbps
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, encoding='utf-8')   #追加, encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")


url = 'https://www.youtube.com/watch?v=7QnAX12M24w'  # 曲目:古典音樂放鬆，安靜的音樂 - 莫扎特，貝多芬，肖邦，Tchaikovsky，Rachmaninov
get_audio_only(url)
# convert_mp4_to_mp3("input.mp4", "output.mp3")# 範例使用
# yt_title = get_audio_only(url)  #返回結果方式

yt_title = global_yt_title     # 定義全局變量

convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')

# media 長度 01:15:53 mp4容量大小71,971KB mp3容量大小71,013KB 處理耗時2m 7.4s

# %%
# V0.85 --> 2024.06.24 final
# 設定包含中英文字 re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles)
# subprocess.run設定encoding='utf-8'
# 以yt_title = get_audio_only(url)返回結果方式(return),取代get_audio_only(url)重複執行

from pytube import YouTube
import re
import subprocess

def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '3',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

url = 'https://www.youtube.com/watch?v=DkurWU1tDI0'  # 曲目:2024宮崎駿鋼琴音樂合集 - 最佳放鬆音樂《100%無廣告》スタジオジブリGhibli Relaxing Music【スターバックス】工作-讀書專用音樂

yt_title = get_audio_only(url)  #返回結果方式

convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')

# media 長度 01:34:55 mp4容量大小90,009KB mp3容量大小90,079KB 處理耗時2m 14.1s-->v0.85

# %%
# V0.9 --> 2024.06.24 final
# test01

from pytube import YouTube
import re
import subprocess

def streams_analysis(url):
    yt = YouTube(url) 
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)


def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '3',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

 
# url = 'https://www.youtube.com/watch?v=2DmfJu3oNDM'  # 曲目:Tchaikovsky: Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra
#柴可夫斯基：第一號鋼琴協奏曲|瑪莎·阿格里奇、夏爾·迪圖瓦和韋爾比耶音樂節管弦樂團

work_item = int(input('輸入 ( 1 :分析   2:下載   其他:跳出執行 )'))
if work_item == 1:
   url = str(input("輸入影音網址 (Enter the url of media) : ")) 
   streams_analysis(url) 
elif work_item == 2:
    url = str(input("輸入影音網址(Enter the url of media) : "))  
    yt_title = get_audio_only(url)  #返回結果方式
    convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')
else:
     print('輸入 ( 1 :分析   2:下載   其他:跳出執行 )')


# media 長度 00:37:50 mp4容量大小35,892KB mp3容量大小39,764KB 處理耗時1m 4.2s-->v0.9
# Out:
# 全名 :  Tchaikovsky: Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra
# Tchaikovsky_ Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra
# 簡稱 :  Tchaikovsky_ Piano Concerto No
# downdload < Tchaikovsky: Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra > 完成
# 轉換成功！輸出文件位於: C:/Users/Lu/Documents/youtube/yt_audio_Tchaikovsky_ Piano Concerto No.mp3

# %%
# V0.9 --> 2024.06.24 final
# test02

from pytube import YouTube
import re
import subprocess

def streams_analysis(url):
    yt = YouTube(url) 
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)


def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '3',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

 
# url = 'https://www.youtube.com/watch?v=yYOOoba2zvU'  # 曲目:Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991)
#柴可夫斯基 - 第一號鋼琴協奏曲 - 巴倫博伊姆、切利比達克、MPO (1991)

work_item = int(input('輸入 ( 1 :分析   2:下載   其他:跳出執行 )'))
if work_item == 1:
   url = str(input("輸入影音網址 (Enter the url of media) : ")) 
   streams_analysis(url) 
elif work_item == 2:
    url = str(input("輸入影音網址(Enter the url of media) : "))  
    yt_title = get_audio_only(url)  #返回結果方式
    convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')
else:
     print('輸入 ( 1 :分析   2:下載   其他:跳出執行 )')


# media 長度 00:37:50 mp4容量大小41,155KB mp3容量大小51,422KB 處理耗時1m 6.2s-->v0.9
# Out:
# 全名 :  Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991)
# Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991)
# 簡稱 :  Tchaikovsky
# downdload < Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991) > 完成
# 轉換成功！輸出文件位於: C:/Users/Lu/Documents/youtube/yt_audio_Tchaikovsky .mp3

# %%
# V0.9 --> 2024.06.24 final
# test03
# convert_mp4_to_mp3    '-q:a', '3', -->'-q:a', '2', (輸出mp3位元速率161kbps-->179kbps)

from pytube import YouTube
import re
import subprocess

def streams_analysis(url):
    yt = YouTube(url) 
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)


def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

 
# url = 'https://www.youtube.com/watch?v=yYOOoba2zvU'  # 曲目:Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991)
#柴可夫斯基 - 第一號鋼琴協奏曲 - 巴倫博伊姆、切利比達克、MPO (1991)

work_item = int(input('輸入 ( 1 :分析   2:下載   其他:跳出執行 )'))
if work_item == 1:
   url = str(input("輸入影音網址 (Enter the url of media) : ")) 
   streams_analysis(url) 
elif work_item == 2:
    url = str(input("輸入影音網址(Enter the url of media) : "))  
    yt_title = get_audio_only(url)  #返回結果方式
    convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')
else:
     print('輸入 ( 1 :分析   2:下載   其他:跳出執行 )')


# media 長度 00:37:50 mp4容量大小41,155KB mp3容量大小57,150KB 處理耗時1m 5.9s-->v0.9
# Out:
# 全名 :  Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991)
# Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991)
# 簡稱 :  Tchaikovsky
# downdload < Tchaikovsky - Piano Concerto No 1 - Barenboim, Celibidache, MPO (1991) > 完成
# 轉換成功！輸出文件位於: C:/Users/Lu/Documents/youtube/yt_audio_Tchaikovsky .mp3

# %%
# V0.9 --> 2024.06.24 final
# test04
# convert_mp4_to_mp3    '-q:a', '3', -->'-q:a', '2', (輸出mp3位元速率143kbps-->158kbps)

from pytube import YouTube
import re
import subprocess

def streams_analysis(url):
    yt = YouTube(url) 
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)


def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

 
# url = 'https://www.youtube.com/watch?v=2DmfJu3oNDM'  # 曲目:Tchaikovsky: Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra
#柴可夫斯基：第一號鋼琴協奏曲|瑪莎·阿格里奇、夏爾·迪圖瓦和韋爾比耶音樂節管弦樂團

work_item = int(input('輸入 ( 1 :分析   2:下載   其他:跳出執行 )'))
if work_item == 1:
   url = str(input("輸入影音網址 (Enter the url of media) : ")) 
   streams_analysis(url) 
elif work_item == 2:
    url = str(input("輸入影音網址(Enter the url of media) : "))  
    yt_title = get_audio_only(url)  #返回結果方式
    convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')
else:
     print('輸入 ( 1 :分析   2:下載   其他:跳出執行 )')


# media 長度 00:37:50 mp4容量大小35,892KB mp3容量大小44,061KB 處理耗時0m 57.7s-->v0.9
# Out:
# 全名 :  Tchaikovsky: Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra
# Tchaikovsky_ Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra
# 簡稱 :  Tchaikovsky_ Piano Concerto No
# downdload < Tchaikovsky: Piano Concerto No. 1 | Martha Argerich, Charles Dutoit & the Verbier Festival Orchestra > 完成
# 轉換成功！輸出文件位於: C:/Users/Lu/Documents/youtube/yt_audio_Tchaikovsky_ Piano Concerto No.mp3

# %%
# V0.9 --> 2024.06.24 final
# test05
# convert_mp4_to_mp3    '-q:a', '2', (輸出mp3位元速率144kbps)

from pytube import YouTube
import re
import subprocess

def streams_analysis(url):
    yt = YouTube(url) 
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)


def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

 
# url = 'https://www.youtube.com/watch?v=ItSJ_woWnmk'  # 曲目:Tchaikovsky Piano Concerto No 1 FULL / Martha Argerich, piano - Charles Dutoit, conductor
#柴可夫斯基第一號鋼琴協奏曲 FULL / 瑪莎·阿格里奇，鋼琴 - 夏爾·迪圖瓦，指揮

work_item = int(input('輸入 ( 1 :分析   2:下載   其他:跳出執行 )'))
if work_item == 1:
   url = str(input("輸入影音網址 (Enter the url of media) : ")) 
   streams_analysis(url) 
elif work_item == 2:
    url = str(input("輸入影音網址(Enter the url of media) : "))  
    yt_title = get_audio_only(url)  #返回結果方式
    convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')
else:
     print('輸入 ( 1 :分析   2:下載   其他:跳出執行 )')


# media 長度 00:34:56 mp4容量大小33,137KB mp3容量大小37,036KB 處理耗時0m 54.2s-->v0.9
# Out:
# 全名 :  Tchaikovsky Piano Concerto No 1 FULL / Martha Argerich, piano - Charles Dutoit, conductor
# Tchaikovsky Piano Concerto No 1 FULL _ Martha Argerich, piano - Charles Dutoit, conductor
# 簡稱 :  Tchaikovsky Piano Concerto No 1 FULL _ Martha Argerich
# downdload < Tchaikovsky Piano Concerto No 1 FULL / Martha Argerich, piano - Charles Dutoit, conductor > 完成
# 轉換成功！輸出文件位於: C:/Users/Lu/Documents/youtube/yt_audio_Tchaikovsky Piano Concerto No 1 FULL _ Martha Argerich.mp3

# %% [markdown]
# @=============================================
# ++++++++++++++++++++++++++++++++++++++++++++++
# 年齡限制視頻-->需要進行身份驗證
#
# pass

# %%
# V0.9 --> 2024.06.24 final
# test06
# convert_mp4_to_mp3    '-q:a', '2', (輸出mp3位元速率144kbps)

from pytube import YouTube
import re
import subprocess

def streams_analysis(url):
    yt = YouTube(url) 
    # 影片格式分析
    print(f'標題: {yt.title}')              # 影片標題
    print(f'長度(s): {yt.length}')          # 影片長度 ( 秒 )
    print(f'作者: {yt.author}')             # 影片作者
    print(f'網址: {yt.channel_url}')        # 影片作者頻道網址
    print(f'縮圖網址: {yt.thumbnail_url}')  # 影片縮圖網址
    print(f'觀看數: {yt.views}')            # 影片觀看數

    # 分析
    print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
    # print(yt.streams.all())  # all()-->useless
    print('影片支援畫質數: ',len(yt.streams))

    for st in yt.streams:
        print(st)


def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '2',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

 
# url = 'https://www.youtube.com/watch?v=xtLoaMfinbU'  # 曲目:Tchaikovsky - The Nutcracker, Ballet in two acts | Mariinsky Theatre (HD 1080p)
#柴可夫斯基 - 胡桃鉗，兩幕芭蕾舞 |馬林斯基劇院（高清 1080p）

work_item = int(input('輸入 ( 1 :分析   2:下載   其他:跳出執行 )'))
if work_item == 1:
   url = str(input("輸入影音網址 (Enter the url of media) : ")) 
   streams_analysis(url) 
elif work_item == 2:
    url = str(input("輸入影音網址(Enter the url of media) : "))  
    yt_title = get_audio_only(url)  #返回結果方式
    convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')
else:
     print('輸入 ( 1 :分析   2:下載   其他:跳出執行 )')


# media 長度 00:34:56 mp4容量大小33,137KB mp3容量大小37,036KB 處理耗時0m 54.2s-->v0.9
# Out:
# 標題: Tchaikovsky - The Nutcracker, Ballet in two acts | Mariinsky Theatre (HD 1080p)
# 長度(s): 6210
# 作者: EuroArtsChannel
# 網址: https://www.youtube.com/channel/UCt7SG8q4GUDMLfbkViwkWLQ
# 縮圖網址: https://i.ytimg.com/vi/xtLoaMfinbU/hq720.jpg
# 觀看數: 19062328
# ---------------------------------------------------------------------------
# AgeRestrictedError                        Traceback (most recent call last)
# Cell In[11], line 74
#      72 if work_item == 1:
#      73    url = str(input("輸入影音網址 (Enter the url of media) : "))
# ---> 74    streams_analysis(url)
#      75 elif work_item == 2:
#      76     url = str(input("輸入影音網址(Enter the url of media) : "))
#
# Cell In[11], line 20, in streams_analysis(url)
#      17 print(f'觀看數: {yt.views}')            # 影片觀看數
#      19 # 分析
# ---> 20 print(f'支援畫質:{yt.streams}')  # 影片支援哪些畫質
#      21 # print(yt.streams.all())  # all()-->useless
#      22 print('影片支援畫質數: ',len(yt.streams))
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:160, in YouTube.streaming_data(self)
#     158     return self.vid_info['streamingData']
#     159 else:
# --> 160     self.bypass_age_gate()
#     161     return self.vid_info['streamingData']
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:264, in YouTube.bypass_age_gate(self)
#     261 # If we still can't access the video, raise an exception
#     262 # (tier 3 age restriction)
#     263 if playability_status == 'UNPLAYABLE':
# --> 264     raise exceptions.AgeRestrictedError(self.video_id)
#     266 self._vid_info = innertube_response
#
# AgeRestrictedError: xtLoaMfinbU is age restricted, and can't be accessed without logging in.

# %%
# V0.85 --> 2024.06.24 final
# 設定包含中英文字 re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles)
# subprocess.run設定encoding='utf-8'
# 以yt_title = get_audio_only(url)返回結果方式(return),取代get_audio_only(url)重複執行

from pytube import YouTube
import re
import subprocess

def get_audio_only(url):
    yt = YouTube(url)   
    print('全名 : ',yt.title)
    list=['/',':','"','<','>','\?','\*']
    yt_titles = yt.title
    for i in list:
        yt_title = re.sub(f'{i}','_',yt_titles)
        yt_titles = yt_title
    print(yt_titles)

    #yt_title = re.search(r'[A-Za-z0-9_ ]+',yt_titles).group()
    yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
    print('簡稱 : ',yt_title)

    yt_audio = yt.streams.filter(abr='128kbps').first()
    yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)  
    print(f'downdload < {yt.title} > 完成')
    return yt_title

def convert_mp4_to_mp3(input_file, output_file):
    command = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-q:a', '3',
        output_file
    ]
    
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,encoding= 'utf-8')  # 設定encoding='utf-8'
        print("轉換成功！輸出文件位於:", output_file)
    except subprocess.CalledProcessError as e:
        print("ffmpeg轉換過程中發生錯誤:", e)
        if e.stderr:
            print("ffmpeg命令輸出:", e.stderr)
        else:
            print("無法獲取 ffmpeg 錯誤輸出。")

url = 'https://www.youtube.com/watch?v=xtLoaMfinbU'  # 曲目:Tchaikovsky - The Nutcracker, Ballet in two acts | Mariinsky Theatre (HD 1080p)
#柴可夫斯基 - 胡桃鉗，兩幕芭蕾舞 |馬林斯基劇院（高清 1080p）

yt_title = get_audio_only(url)  #返回結果方式

convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')

# media 長度 01:34:55 mp4容量大小90,009KB mp3容量大小90,079KB 處理耗時2m 14.1s-->v0.85
# Out:
# 全名 :  Tchaikovsky - The Nutcracker, Ballet in two acts | Mariinsky Theatre (HD 1080p)
# Tchaikovsky - The Nutcracker, Ballet in two acts | Mariinsky Theatre (HD 1080p)
# 簡稱 :  Tchaikovsky
# ---------------------------------------------------------------------------
# AgeRestrictedError                        Traceback (most recent call last)
# Cell In[12], line 52
#      49 url = 'https://www.youtube.com/watch?v=xtLoaMfinbU'  # 曲目:Tchaikovsky - The Nutcracker, Ballet in two acts | Mariinsky Theatre (HD 1080p)
#      50 #柴可夫斯基 - 胡桃鉗，兩幕芭蕾舞 |馬林斯基劇院（高清 1080p）
# ---> 52 yt_title = get_audio_only(url)  #返回結果方式
#      54 convert_mp4_to_mp3(f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp4', f'C:/Users/Lu/Documents/youtube/yt_audio_{yt_title}.mp3')
#      56 # media 長度 01:34:55 mp4容量大小90,009KB mp3容量大小90,079KB 處理耗時2m 14.1s-->v0.85
#
# Cell In[12], line 24, in get_audio_only(url)
#      21 yt_title = re.search(r'[\w\u4e00-\u9fff\s]+',yt_titles).group() #設定包含中英文字
#      22 print('簡稱 : ',yt_title)
# ---> 24 yt_audio = yt.streams.filter(abr='128kbps').first()
#      25 yt_audio.download(output_path='C:/Users/Lu/Documents/youtube',filename=f'yt_audio_{yt_title}.mp4', skip_existing=True, max_retries=0)
#      26 print(f'downdload < {yt.title} > 完成')
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:296, in YouTube.streams(self)
#     291 """Interface to query both adaptive (DASH) and progressive streams.
#     292
#     293 :rtype: :class:`StreamQuery <StreamQuery>`.
#     294 """
#     295 self.check_availability()
# --> 296 return StreamQuery(self.fmt_streams)
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:176, in YouTube.fmt_streams(self)
#     172     return self._fmt_streams
#     174 self._fmt_streams = []
# --> 176 stream_manifest = extract.apply_descrambler(self.streaming_data)
#     178 # If the cached js doesn't work, try fetching a new js file
#     179 # https://github.com/pytube/pytube/issues/1054
#     180 try:
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:160, in YouTube.streaming_data(self)
#     158     return self.vid_info['streamingData']
#     159 else:
# --> 160     self.bypass_age_gate()
#     161     return self.vid_info['streamingData']
#
# File c:\Users\Lu\Documents\GitHub\__2024_01_08_python_openAPI__\__youtube_download__\yt.venv\lib\site-packages\pytube\__main__.py:264, in YouTube.bypass_age_gate(self)
#     261 # If we still can't access the video, raise an exception
#     262 # (tier 3 age restriction)
#     263 if playability_status == 'UNPLAYABLE':
# --> 264     raise exceptions.AgeRestrictedError(self.video_id)
#     266 self._vid_info = innertube_response
#
# AgeRestrictedError: xtLoaMfinbU is age restricted, and can't be accessed without logging in.

# %% [markdown]
# pass
# 年齡限制視頻-->需要進行身份驗證
# ++++++++++  ~ End ~ +++++++++++++++++
# @=========================================================

# %% [markdown]
# #### 透過chatGPT -1
# ##### Question :
# 在yt = YouTube(url)   ;print(f'支援畫質:{yt.streams}')，
# 發生AgeRestrictedError: xtLoaMfinbU is age restricted, and can't be accessed without logging in.，如何處理？？
# ##### Answer :
# YouTube 年齡限制視頻需要進行身份驗證才能訪問。pytube 支持 OAuth 驗證，可以使用它來處理需要登錄的情況。
#
# pass

# %% [markdown]
# pass
# 年齡限制視頻-->需要進行身份驗證
# ++++++++++  ~ End ~ +++++++++++++++++
# @=====================================
